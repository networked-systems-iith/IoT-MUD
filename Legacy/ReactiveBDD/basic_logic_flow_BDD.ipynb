# %%
import pandas as pd
import json
import glob
import os       
import xlsxwriter

# %%
df1 = pd.read_csv (r'./total_rules.csv')

# %%
print(df1)
# Out:
#                 sEth               dEth  typEth           Source  \
# 0  9e:8d:de:80:29:28  ff:ff:ff:ff:ff:ff  0x0800  s1b.time.edu.cn
# 1                  *  9e:8d:de:80:29:28  0x0800  fr.pool.ntp.org
# 2  9e:8d:de:80:29:28  ff:ff:ff:ff:ff:ff  0x0800  de.pool.ntp.org
# 3  9e:8d:de:80:29:28  ff:ff:ff:ff:ff:ff  0x0006  us.pool.ntp.org
# 4                  *  9e:8d:de:80:29:28  0x0800  ca.pool.ntp.org
#
#                     Destination  proto  sPort  dPort   action
# 0           dcape-na.amazon.com     17    123    443  forward
# 1    softwareupdates.amazon.com     17    123     80  forward
# 2  3.north-america.pool.ntp.org     17    123     53  forward
# 3                 224.0.0.22/32     17    123     67  forward
# 4            239.255.255.250/32     17    123  33434  forward

# %%
data=df1.values.tolist()
print(data)
# Out:
# [['9e:8d:de:80:29:28', 'ff:ff:ff:ff:ff:ff', '0x0800', 's1b.time.edu.cn', 'dcape-na.amazon.com', 17, 123, 443, 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', 'fr.pool.ntp.org', 'softwareupdates.amazon.com', 17, 123, 80, 'forward'], ['9e:8d:de:80:29:28', 'ff:ff:ff:ff:ff:ff', '0x0800', 'de.pool.ntp.org', '3.north-america.pool.ntp.org', 17, 123, 53, 'forward'], ['9e:8d:de:80:29:28', 'ff:ff:ff:ff:ff:ff', '0x0006', 'us.pool.ntp.org', '224.0.0.22/32', 17, 123, 67, 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', 'ca.pool.ntp.org', '239.255.255.250/32', 17, 123, 33434, 'forward']]

# %%
columns=df1.columns

# %%
#for i in range(len(data)):
length=len(data[0])

# %%
outworkbook=xlsxwriter.Workbook("out.xlsx")
#outsheet=outworkbook.add_worksheet()
#outsheet8=outworkbook.add_worksheet()

# %%
workbook1=xlsxwriter.Workbook("output.xlsx")

# %%
for j in range(0,length):
    outsheet=workbook1.add_worksheet(columns[j])

# %%
workbook1.sheetnames
# Out:
# {'sEth': <xlsxwriter.worksheet.Worksheet at 0x44d1a78>,
#  'dEth': <xlsxwriter.worksheet.Worksheet at 0x44d1bb0>,
#  'typEth': <xlsxwriter.worksheet.Worksheet at 0x44d1be0>,
#  'Source': <xlsxwriter.worksheet.Worksheet at 0x44d1bf8>,
#  'Destination': <xlsxwriter.worksheet.Worksheet at 0x44d1c28>,
#  'proto': <xlsxwriter.worksheet.Worksheet at 0x44d1b80>,
#  'sPort': <xlsxwriter.worksheet.Worksheet at 0x44d1b68>,
#  'dPort': <xlsxwriter.worksheet.Worksheet at 0x44d1ad8>,
#  'action': <xlsxwriter.worksheet.Worksheet at 0x44d1b50>}

# %%
counter=1
count=[]

# %%
length=len(data)
for i in range(len(data)) :
    length=len(data[i])
    for j in range(len(data[i])) :
        if j==0:
            print(data[i][j],'-',counter)
            workbook1.sheetnames[columns[j]].write("A1","sEth")
            workbook1.sheetnames[columns[j]].write("B1","state")
            #for k in range(0,len(data)):
                #if data[k][j]==data[i][j]:
                    #break
                    
            workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
            #print(i)
            #k=k+1
            workbook1.sheetnames[columns[j]].write(i+1,1,counter)
            count.append(counter)
            #print(i)
            #m=m+1
            previous_counter=counter
            counter=counter+1
        elif j==length-1:
            print(previous_counter,'-',data[i][j])
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1","Action")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            #n=n+1
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            #o=o+1
            #counter=counter+1
        else:
            print(previous_counter,'-',data[i][j],'-',counter)
            #outsheetj.write("A1","Previous_state")
            #outsheetj.write("B1",columns[j])
            #outsheetj.write("C1","next_state")
            #outsheetj.write(i+1,0,previous_counter)
            #outsheetj.write(i+1,1,data[i][j])
            #outsheetj.write(i+1,2,counter)
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
            workbook1.sheetnames[columns[j]].write("C1","next_state")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            workbook1.sheetnames[columns[j]].write(i+1,2,counter)
            #sheet_name1.write()
            #sheet_name=columns[j]
            #print(column[j])
            #worksheet=outworkbook.add_worksheet(sheet_name)
            previous_counter=counter
            counter=counter+1
# Out:
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - s1b.time.edu.cn - 4
# 4 - dcape-na.amazon.com - 5
# 5 - 17 - 6
# 6 - 123 - 7
# 7 - 443 - 8
# 8 - forward
# * - 9
# 9 - 9e:8d:de:80:29:28 - 10
# 10 - 0x0800 - 11
# 11 - fr.pool.ntp.org - 12
# 12 - softwareupdates.amazon.com - 13
# 13 - 17 - 14
# 14 - 123 - 15
# 15 - 80 - 16
# 16 - forward
# 9e:8d:de:80:29:28 - 17
# 17 - ff:ff:ff:ff:ff:ff - 18
# 18 - 0x0800 - 19
# 19 - de.pool.ntp.org - 20
# 20 - 3.north-america.pool.ntp.org - 21
# 21 - 17 - 22
# 22 - 123 - 23
# 23 - 53 - 24
# 24 - forward

# %%
workbook1.close()

# %%
#remove duplicates only for first column
counter=1
count=[]
for i in range(len(data)) :
    length=len(data[i])
    for j in range(len(data[i])) :
        if j==0:
            if i==0:
                print(data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","sEth")
                workbook1.sheetnames[columns[j]].write("B1","state")
                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                count.append(counter)
                previous_counter=counter
                counter=counter+1
            else:
                 for k in range(0,i):
                #print(k)
                        if data[k][j]==data[i][j]:
                        #print(data[i][j])
                        #print(k)
                        #break
                            previous_counter=count[k]

                            print(data[i][j],'-',previous_counter)
                            break
                        for k in range(0,i):
                            if data[k][j]!=data[i][j]:
                                print(data[i][j],'-',counter)
                                workbook1.sheetnames[columns[j]].write("A1","sEth")
                                workbook1.sheetnames[columns[j]].write("B1","state")
                                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                                count.append(counter)
                                previous_counter=counter
                                counter=counter+1
        elif j==length-1:
            print(previous_counter,'-',data[i][j])
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1","Action")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            #n=n+1
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            #o=o+1
            #counter=counter+1
        else:
            
            print(previous_counter,'-',data[i][j],'-',counter)
            #outsheetj.write("A1","Previous_state")
            #outsheetj.write("B1",columns[j])
            #outsheetj.write("C1","next_state")
            #outsheetj.write(i+1,0,previous_counter)
            #outsheetj.write(i+1,1,data[i][j])
            #outsheetj.write(i+1,2,counter)
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
            workbook1.sheetnames[columns[j]].write("C1","next_state")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            workbook1.sheetnames[columns[j]].write(i+1,2,counter)
            #sheet_name1.write()
            #sheet_name=columns[j]
            #print(column[j])
            #worksheet=outworkbook.add_worksheet(sheet_name)
            previous_counter=counter
            counter=counter+1
# Out:
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - s1b.time.edu.cn - 4
# 4 - dcape-na.amazon.com - 5
# 5 - 17 - 6
# 6 - 123 - 7
# 7 - 443 - 8
# 8 - forward
# * - 9
# 9 - 9e:8d:de:80:29:28 - 10
# 10 - 0x0800 - 11
# 11 - fr.pool.ntp.org - 12
# 12 - softwareupdates.amazon.com - 13
# 13 - 17 - 14
# 14 - 123 - 15
# 15 - 80 - 16
# 16 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 17
# 17 - 0x0800 - 18
# 18 - de.pool.ntp.org - 19
# 19 - 3.north-america.pool.ntp.org - 20
# 20 - 17 - 21
# 21 - 123 - 22
# 22 - 53 - 23
# 23 - forward

# %%
i=2
for k in range(0,i):
    print(k)
    print(count[k])
# Out:
# 0
# 1
# 1
# 9

# %%
counter=1
count=[]
previous_count=[[]]
for i in range(len(data)) :
    length=len(data[i])
    for j in range(len(data[i])) :
        if j==0:
            if i==0:
                print(data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","sEth")
                workbook1.sheetnames[columns[j]].write("B1","state")
                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                count.append(counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
            else:
                 for k in range(0,i):
                #print(k)
                        if data[k][j]==data[i][j]:
                        #print(data[i][j])
                        #print(k)
                        #break
                            previous_counter=count[k]
                            #previous_count[i][j]=previous_counter
                            print(data[i][j],'-',previous_counter)
                            break
                        for k in range(0,i):
                            if data[k][j]!=data[i][j]:
                                print(data[i][j],'-',counter)
                                workbook1.sheetnames[columns[j]].write("A1","sEth")
                                workbook1.sheetnames[columns[j]].write("B1","state")
                                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                                count.append(counter)
                                previous_counter=counter
                                #previous_count[i][j]=previous_counter
                                counter=counter+1
        elif j==length-1:
            print(previous_counter,'-',data[i][j])
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1","Action")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            #n=n+1
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            #o=o+1
            #counter=counter+1
        else:
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                previous_count[i].append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                previous_counter=counter
                counter=counter+1
            else:
                for k in range(0,i):
                    if data[k][j]!=data[i][j]:
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_count[i].append(previous_counter)
                        workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                        workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                        workbook1.sheetnames[columns[j]].write("C1","next_state")
                        workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                        workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                        workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                        count.append(counter)
                        previous_counter=counter
                        #previous_count[i][j]=previous_counter
                        counter=counter+1
                #for k in range(0,i):
                    #if data[k][j]==data[i][j]:
                        
                        
                       
                #for k in range(0,i):
                    #if data[k][j]==data[i][j]:
# Out:
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - s1b.time.edu.cn - 4
# 4 - dcape-na.amazon.com - 5
# 5 - 17 - 6
# 6 - 123 - 7
# 7 - 443 - 8
# 8 - forward
# * - 9
# 9 - 9e:8d:de:80:29:28 - 10
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-8afa69ec212b> in <module>
#      73                     if data[k][j]!=data[i][j]:
#      74                         print(previous_counter,'-',data[i][j],'-',counter)
# ---> 75                         previous_count[j].append(previous_counter)
#      76                         workbook1.sheetnames[columns[j]].write("A1","Previous_state")
#      77                         workbook1.sheetnames[columns[j]].write("B1", columns[j])
#
# IndexError: list index out of range

# %%
previous_count=[[]]

# %%
counter=1
previous_count=[[]]
for i in range(len(data)):
    for j in range(len(data[i])) :
        if j>0:
            previous_counter=counter
            #previous_count[j].append(previous_counter)
            #previous_count[j][i]=previous-counter
            counter=counter+1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-615b519c1915> in <module>
#       6             previous_counter=counter
#       7             temo=j
# ----> 8             previous_count[i][temo]=previous_counter
#       9
#      10             #previous_count[j].append(previous_counter)
#
# IndexError: list assignment index out of range

# %%
counter=1
count=[]
count1=[]
previous_count=[]
for i in range(len(data)) :
    length=len(data[i])
    for j in range(len(data[i])) :
        if j==0:
            if i==0:
                print(data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","sEth")
                workbook1.sheetnames[columns[j]].write("B1","state")
                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                count.append(counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
            else:
                 for k in range(0,i):
                #print(k)
                        if data[k][j]==data[i][j]:
                        #print(data[i][j])
                        #print(k)
                        #break
                            previous_counter=count[k]
                            #previous_count[i][j]=previous_counter
                            print(data[i][j],'-',previous_counter)
                            break
                        for k in range(0,i):
                            if data[k][j]!=data[i][j]:
                                print(data[i][j],'-',counter)
                                workbook1.sheetnames[columns[j]].write("A1","sEth")
                                workbook1.sheetnames[columns[j]].write("B1","state")
                                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                                count.append(counter)
                                previous_counter=counter
                                #previous_count[i][j]=previous_counter
                                counter=counter+1
        elif j==length-1:
            print(previous_counter,'-',data[i][j])
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1","Action")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            #n=n+1
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            #o=o+1
            #counter=counter+1
        elif j==1:
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                previous_count.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count1.append(counter)
                previous_counter=counter
                counter=counter+1
            else:
                
                for k in range(0,i):
                    #print("previous value",data[k][j])
                    if data[k][j]==data[i][j]: 
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count[k]==previous_counter:
                            counter=count1[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            break
                        elif previous_count[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_count.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count1.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                    for k in range(0,i):
                    #print(data[k][j])
                        if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)
                        
                        #print(data[i][j])
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_count.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count1.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
# Out:
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - forward
# * - 3
# 3 - 9e:8d:de:80:29:28 - 4
# 4 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - forward

# %%
counter=1
counter1=0
count=[]
count1=[]
count2=[]
previous_count=[]
previous_count1=[]
for i in range(len(data)) :
    length=len(data[i])
    for j in range(len(data[i])) :
        if j==0:
            if i==0:
                print(data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","sEth")
                workbook1.sheetnames[columns[j]].write("B1","state")
                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                count.append(counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
            else:
                 for k in range(0,i):
                #print(k)
                        if data[k][j]==data[i][j]:
                        #print(data[i][j])
                        #print(k)
                        #break
                            previous_counter=count[k]
                            #previous_count[i][j]=previous_counter
                            print(data[i][j],'-',previous_counter)
                            break
                        for k in range(0,i):
                            if data[k][j]!=data[i][j]:
                                print(data[i][j],'-',counter)
                                workbook1.sheetnames[columns[j]].write("A1","sEth")
                                workbook1.sheetnames[columns[j]].write("B1","state")
                                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                                count.append(counter)
                                previous_counter=counter
                                #previous_count[i][j]=previous_counter
                                counter=counter+1
        elif j==length-1:
            print(previous_counter,'-',data[i][j])
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1","Action")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            #n=n+1
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            #o=o+1
            #counter=counter+1
        elif j==1:
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                previous_count.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count1.append(counter)
                previous_counter=counter
                counter=counter+1
            else:
                
                for k in range(0,i):
                    #print("previous value",data[k][j])
                    if data[k][j]==data[i][j]: 
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count[k]==previous_counter:
                            counter=count1[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            break
                        elif previous_count[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_count.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count1.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                    for k in range(0,i):
                    #print(data[k][j])
                        if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)
                        
                        #print(data[i][j])
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_count.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count1.append(counter)
                            previous_counter=counter
                            counter=counter+1
                            #previous_count[i][j]=previous_counter
        elif j==2:
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                previous_count1.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count2.append(counter)
                previous_counter=counter
                counter=counter+1
            else:
                
                for k in range(0,i):
                    #print("previous value",data[k][j])
                    if data[k][j]==data[i][j]: 
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count1[k]==previous_counter:
                            counter=count2[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            break
                        elif previous_count1[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_count1.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count2.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                    for k in range(0,i):
                    #print(data[k][j])
                        if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)
                        
                        #print(data[i][j])
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_count1.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count2.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #counter=counter+1
# Out:
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - forward
# * - 4
# 4 - 9e:8d:de:80:29:28 - 5
# 5 - 0x0800 - 6
# 6 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - forward

# %%
counter=1
counter1=0
count=[]
count1=[]
count2=[]
count3=[]
previous_count=[]
previous_count1=[]
previous_count2=[]
for i in range(len(data)) :
    length=len(data[i])
    for j in range(len(data[i])) :
        if j==0:
            flag3=0
            if i==0:
                print(data[i][j],'-',counter)
                #print(data[i][j],'-',temp)
                workbook1.sheetnames[columns[j]].write("A1","sEth")
                workbook1.sheetnames[columns[j]].write("B1","state")
                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                count.append(counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                 for k in range(0,i):
                #print(k)
                        if data[k][j]==data[i][j]:
                        #print(data[i][j])
                        #print(k)
                        #break
                            previous_counter=count[k]
                            #previous_count[i][j]=previous_counter
                            print(data[i][j],'-',previous_counter)
                            break
                        for k in range(0,i):
                            if data[k][j]!=data[i][j]:
                                print(data[i][j],'-',counter)
                                #print(data[i][j],'-',temp)
                                workbook1.sheetnames[columns[j]].write("A1","sEth")
                                workbook1.sheetnames[columns[j]].write("B1","state")
                                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                                count.append(counter)
                                previous_counter=counter
                                #previous_count[i][j]=previous_counter
                                counter=counter+1
                                temp=counter
        elif j==length-1:
            print(previous_counter,'-',data[i][j])
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1","Action")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            #n=n+1
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            temp=previous_counter+1
            #o=o+1
            #counter=counter+1
        elif j==1:
            flag2=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count1.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp=counter
            else:
                
                for k in range(0,i):
                    #print("previous value",data[k][j])
                    if data[k][j]==data[i][j]: 
                        flag2=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count[k]==previous_counter:
                            counter=count1[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            break
                        elif previous_count[k]!=previous_counter:
                            #count_max=max(temp,counter)
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',count_max)
                            previous_count.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count1.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                #for k in range(0,i):
                if flag2==0:
                    
                    #print(data[k][j])
                        #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)
                        
                        #print(data[i][j])
                    count_max=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    #print(previous_counter,'-',data[i][j],'-',temp)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count1.append(counter)
                    previous_counter=counter
                    counter=counter+1
                            #temp=counter
                            #previous_count[i][j]=previous_counter
        elif j==2:
            flag1=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count1.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count2.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp=counter
            else:
                
                for k in range(0,i):
                    #print("previous value",data[k][j])
                    if data[k][j]==data[i][j]: 
                        flag1=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count1[k]==previous_counter:
                            counter=count2[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            break
                        elif previous_count1[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count1.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count2.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                    #for k in range(0,i):
                if flag1==0:
                    #print(data[k][j])
                        #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)
                        
                        #print(data[i][j])
                    #counter=temp
                    count_max=max(temp,counter)
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count1.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count2.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
                    #temp=counter
                    #counter=counter+1
        elif j==3:
            flag=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count2.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count3.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count2[k]==previous_counter:
                            counter=count3[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count2[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count2.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count3.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count2.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count3.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
# Out:
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - s1b.time.edu.cn - 4
# 4 - forward
# * - 5
# 5 - 9e:8d:de:80:29:28 - 6
# 5 - 9e:8d:de:80:29:28 - 6
# 6 - 0x0800 - 7
# 7 - fr.pool.ntp.org - 8
# 8 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - de.pool.ntp.org - 9
# 9 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0006 - 10
# 10 - us.pool.ntp.org - 11
# 11 - forward

# %%
count
# Out:
# [1, 5]

# %%
counter=1
counter1=0
count=[]
count1=[]
count2=[]
count3=[]
count4=[]
count5=[]
count6=[]
previous_count=[]
previous_count1=[]
previous_count2=[]
previous_count3=[]
previous_count4=[]
previous_count5=[]
for i in range(len(data)) :
    length=len(data[i])
    for j in range(len(data[i])) :
        if j==0:
            flag3=0
            if i==0:
                print(data[i][j],'-',counter)
                #print(data[i][j],'-',temp)
                workbook1.sheetnames[columns[j]].write("A1","sEth")
                workbook1.sheetnames[columns[j]].write("B1","state")
                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                count.append(counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                 for k in range(0,i):
                #print(k)
                        if data[k][j]==data[i][j]:
                        #print(data[i][j])
                        #print(k)
                        #break
                            previous_counter=count[k]
                            #previous_count[i][j]=previous_counter
                            print(data[i][j],'-',previous_counter)
                            break
                        for k in range(0,i):
                            if data[k][j]!=data[i][j]:
                                print(data[i][j],'-',counter)
                                #print(data[i][j],'-',temp)
                                workbook1.sheetnames[columns[j]].write("A1","sEth")
                                workbook1.sheetnames[columns[j]].write("B1","state")
                                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                                count.append(counter)
                                previous_counter=counter
                                #previous_count[i][j]=previous_counter
                                counter=counter+1
                                temp=counter
        elif j==length-1:
            print(previous_counter,'-',data[i][j])
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1","Action")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            #n=n+1
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            temp=previous_counter+1
            #o=o+1
            #counter=counter+1
        elif j==1:
            flag2=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count1.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp=counter
            else:
                
                for k in range(0,i):
                    #print("previous value",data[k][j])
                    if data[k][j]==data[i][j]: 
                        flag2=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count[k]==previous_counter:
                            counter=count1[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            break
                        elif previous_count[k]!=previous_counter:
                            #count_max=max(temp,counter)
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',count_max)
                            previous_count.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count1.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                #for k in range(0,i):
                if flag2==0:
                    
                    #print(data[k][j])
                        #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)
                        
                        #print(data[i][j])
                    count_max=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    #print(previous_counter,'-',data[i][j],'-',temp)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count1.append(counter)
                    previous_counter=counter
                    counter=counter+1
                            #temp=counter
                            #previous_count[i][j]=previous_counter
        elif j==2:
            flag1=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count1.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count2.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp=counter
            else:
                
                for k in range(0,i):
                    #print("previous value",data[k][j])
                    if data[k][j]==data[i][j]: 
                        flag1=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count1[k]==previous_counter:
                            counter=count2[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            break
                        elif previous_count1[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count1.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count2.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                    #for k in range(0,i):
                if flag1==0:
                    #print(data[k][j])
                        #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)
                        
                        #print(data[i][j])
                    #counter=temp
                    count_max=max(temp,counter)
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count1.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count2.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
                    #temp=counter
                    #counter=counter+1
        elif j==3:
            flag=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count2.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count3.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count2[k]==previous_counter:
                            counter=count3[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count2[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count2.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count3.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count2.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count3.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==4:
            flag4=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count3.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count4.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag4=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count3[k]==previous_counter:
                            counter=count4[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count3[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count3.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count4.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag4==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count3.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count4.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==5:
            flag5=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count4.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count5.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag5=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count4[k]==previous_counter:
                            counter=count5[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count4[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count4.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count5.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            break
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag5==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count4.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count5.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==6:
            flag6=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count4.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count5.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag5=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count4[k]==previous_counter:
                            counter=count5[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count4[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count4.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count5.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            break
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag5==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count4.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count5.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
# Out:
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - s1b.time.edu.cn - 4
# 4 - dcape-na.amazon.com - 5
# 5 - 17 - 6
# 6 - forward
# * - 7
# 7 - 9e:8d:de:80:29:28 - 8
# 7 - 9e:8d:de:80:29:28 - 8
# 8 - 0x0800 - 9
# 9 - fr.pool.ntp.org - 10
# 10 - softwareupdates.amazon.com - 11
# 11 - 17 - 12
# 12 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - de.pool.ntp.org - 13
# 13 - 3.north-america.pool.ntp.org - 14
# 14 - 17 - 15
# 15 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0006 - 16
# 16 - us.pool.ntp.org - 17
# 17 - 224.0.0.22/32 - 18
# 18 - 17 - 19
# 19 - forward

# %%
counter=1
counter1=0
count=[]
count1=[]
count2=[]
count3=[]
count4=[]
count5=[]
count6=[]
count7=[]
previous_count=[]
previous_count1=[]
previous_count2=[]
previous_count3=[]
previous_count4=[]
previous_count5=[]
previous_count6=[]
for i in range(len(data)) :
    length=len(data[i])
    for j in range(len(data[i])) :
        if j==0:
            flag3=0
            if i==0:
                print(data[i][j],'-',counter)
                #print(data[i][j],'-',temp)
                workbook1.sheetnames[columns[j]].write("A1","sEth")
                workbook1.sheetnames[columns[j]].write("B1","state")
                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                count.append(counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                 for k in range(0,i):
                #print(k)
                        if data[k][j]==data[i][j]:
                        #print(data[i][j])
                        #print(k)
                        #break
                            previous_counter=count[k]
                            #previous_count[i][j]=previous_counter
                            print(data[i][j],'-',previous_counter)
                            break
                        for k in range(0,i):
                            if data[k][j]!=data[i][j]:
                                print(data[i][j],'-',counter)
                                #print(data[i][j],'-',temp)
                                workbook1.sheetnames[columns[j]].write("A1","sEth")
                                workbook1.sheetnames[columns[j]].write("B1","state")
                                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                                count.append(counter)
                                previous_counter=counter
                                #previous_count[i][j]=previous_counter
                                counter=counter+1
                                temp=counter
        elif j==length-1:
            print(previous_counter,'-',data[i][j])
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1","Action")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            #n=n+1
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            temp=previous_counter+1
            #o=o+1
            #counter=counter+1
        elif j==1:
            flag2=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count1.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp=counter
            else:
                
                for k in range(0,i):
                    #print("previous value",data[k][j])
                    if data[k][j]==data[i][j]: 
                        flag2=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count[k]==previous_counter:
                            counter=count1[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            break
                        elif previous_count[k]!=previous_counter:
                            #count_max=max(temp,counter)
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',count_max)
                            previous_count.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count1.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                #for k in range(0,i):
                if flag2==0:
                    
                    #print(data[k][j])
                        #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)
                        
                        #print(data[i][j])
                    count_max=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    #print(previous_counter,'-',data[i][j],'-',temp)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count1.append(counter)
                    previous_counter=counter
                    counter=counter+1
                            #temp=counter
                            #previous_count[i][j]=previous_counter
        elif j==2:
            flag1=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count1.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count2.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp=counter
            else:
                
                for k in range(0,i):
                    #print("previous value",data[k][j])
                    if data[k][j]==data[i][j]: 
                        flag1=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count1[k]==previous_counter:
                            counter=count2[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            break
                        elif previous_count1[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count1.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count2.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                    #for k in range(0,i):
                if flag1==0:
                    #print(data[k][j])
                        #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)
                        
                        #print(data[i][j])
                    #counter=temp
                    count_max=max(temp,counter)
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count1.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count2.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
                    #temp=counter
                    #counter=counter+1
        elif j==3:
            flag=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count2.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count3.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count2[k]==previous_counter:
                            counter=count3[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count2[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count2.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count3.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count2.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count3.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==4:
            flag4=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count3.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count4.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag4=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count3[k]==previous_counter:
                            counter=count4[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count3[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count3.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count4.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag4==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count3.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count4.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==5:
            flag5=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count4.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count5.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag5=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count4[k]==previous_counter:
                            counter=count5[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count4[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count4.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count5.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            break
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag5==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count4.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count5.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==6:
            flag6=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count5.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count6.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag6=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count5[k]==previous_counter:
                            counter=count6[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count5[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count5.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count6.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            break
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag6==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count5.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count6.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
# Out:
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - s1b.time.edu.cn - 4
# 4 - dcape-na.amazon.com - 5
# 5 - 17 - 6
# 6 - 123 - 7
# 7 - forward
# * - 8
# 8 - 9e:8d:de:80:29:28 - 9
# 8 - 9e:8d:de:80:29:28 - 9
# 9 - 0x0800 - 10
# 10 - fr.pool.ntp.org - 11
# 11 - softwareupdates.amazon.com - 12
# 12 - 17 - 13
# 13 - 123 - 14
# 14 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - de.pool.ntp.org - 15
# 15 - 3.north-america.pool.ntp.org - 16
# 16 - 17 - 17
# 17 - 123 - 18
# 18 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0006 - 19
# 19 - us.pool.ntp.org - 20
# 20 - 224.0.0.22/32 - 21
# 21 - 17 - 22
# 22 - 123 - 23
# 23 - forward

# %%
counter=1
counter1=0
count=[]
count1=[]
count2=[]
count3=[]
count4=[]
count5=[]
count6=[]
count7=[]
previous_count=[]
previous_count1=[]
previous_count2=[]
previous_count3=[]
previous_count4=[]
previous_count5=[]
previous_count6=[]
for i in range(len(data)) :
    length=len(data[i])
    for j in range(len(data[i])) :
        if j==0:
            flag3=0
            if i==0:
                print(data[i][j],'-',counter)
                #print(data[i][j],'-',temp)
                workbook1.sheetnames[columns[j]].write("A1","sEth")
                workbook1.sheetnames[columns[j]].write("B1","state")
                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                count.append(counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                 for k in range(0,i):
                #print(k)
                        if data[k][j]==data[i][j]:
                        #print(data[i][j])
                        #print(k)
                        #break
                            previous_counter=count[k]
                            #previous_count[i][j]=previous_counter
                            print(data[i][j],'-',previous_counter)
                            break
                        for k in range(0,i):
                            if data[k][j]!=data[i][j]:
                                print(data[i][j],'-',counter)
                                #print(data[i][j],'-',temp)
                                workbook1.sheetnames[columns[j]].write("A1","sEth")
                                workbook1.sheetnames[columns[j]].write("B1","state")
                                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                                count.append(counter)
                                previous_counter=counter
                                #previous_count[i][j]=previous_counter
                                counter=counter+1
                                temp=counter
        elif j==length-1:
            print(previous_counter,'-',data[i][j])
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1","Action")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            #n=n+1
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            temp=previous_counter+1
            #o=o+1
            #counter=counter+1
        elif j==1:
            flag2=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count1.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp=counter
            else:
                
                for k in range(0,i):
                    #print("previous value",data[k][j])
                    if data[k][j]==data[i][j]: 
                        flag2=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count[k]==previous_counter:
                            counter=count1[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            break
                        elif previous_count[k]!=previous_counter:
                            #count_max=max(temp,counter)
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',count_max)
                            previous_count.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count1.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                #for k in range(0,i):
                if flag2==0:
                    
                    #print(data[k][j])
                        #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)
                        
                        #print(data[i][j])
                    count_max=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    #print(previous_counter,'-',data[i][j],'-',temp)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count1.append(counter)
                    previous_counter=counter
                    counter=counter+1
                            #temp=counter
                            #previous_count[i][j]=previous_counter
        elif j==2:
            flag1=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count1.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count2.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp=counter
            else:
                
                for k in range(0,i):
                    #print("previous value",data[k][j])
                    if data[k][j]==data[i][j]: 
                        flag1=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count1[k]==previous_counter:
                            counter=count2[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            break
                        elif previous_count1[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count1.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count2.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                    #for k in range(0,i):
                if flag1==0:
                    #print(data[k][j])
                        #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)
                        
                        #print(data[i][j])
                    #counter=temp
                    count_max=max(temp,counter)
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count1.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count2.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
                    #temp=counter
                    #counter=counter+1
        elif j==3:
            flag=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count2.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count3.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count2[k]==previous_counter:
                            counter=count3[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count2[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count2.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count3.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count2.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count3.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==4:
            flag4=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count3.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count4.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag4=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count3[k]==previous_counter:
                            counter=count4[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count3[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count3.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count4.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag4==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count3.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count4.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==5:
            flag5=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count4.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count5.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag5=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count4[k]==previous_counter:
                            counter=count5[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count4[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count4.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count5.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            break
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag5==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count4.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count5.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==6:
            flag6=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count5.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count6.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag6=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count5[k]==previous_counter:
                            counter=count6[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count5[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count5.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count6.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            break
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag6==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count5.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count6.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==7:
            flag7=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count6.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count7.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag7=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count6[k]==previous_counter:
                            counter=count7[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count6[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count6.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count7.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            break
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag7==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count6.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count7.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
# Out:
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - s1b.time.edu.cn - 4
# 4 - dcape-na.amazon.com - 5
# 5 - 17 - 6
# 6 - 123 - 7
# 7 - 443 - 8
# 8 - forward
# * - 9
# 9 - 9e:8d:de:80:29:28 - 10
# 9 - 9e:8d:de:80:29:28 - 10
# 10 - 0x0800 - 11
# 11 - fr.pool.ntp.org - 12
# 12 - softwareupdates.amazon.com - 13
# 13 - 17 - 14
# 14 - 123 - 15
# 15 - 80 - 16
# 16 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - de.pool.ntp.org - 17
# 17 - 3.north-america.pool.ntp.org - 18
# 18 - 17 - 19
# 19 - 123 - 20
# 20 - 53 - 21
# 21 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0006 - 22
# 22 - us.pool.ntp.org - 23
# 23 - 224.0.0.22/32 - 24
# 24 - 17 - 25
# 25 - 123 - 26
# 26 - 67 - 27
# 27 - forward

# %%
counter=1
counter1=0
count=[]
count1=[]
count2=[]
count3=[]
count4=[]
count5=[]
count6=[]
count7=[]
previous_count=[]
previous_count1=[]
previous_count2=[]
previous_count3=[]
previous_count4=[]
previous_count5=[]
previous_count6=[]
for i in range(len(data)) :
    length=len(data[i])
    for j in range(len(data[i])) :
        if j==0:
            flag3=0
            if i==0:
                print(data[i][j],'-',counter)
                #print(data[i][j],'-',temp)
                workbook1.sheetnames[columns[j]].write("A1","sEth")
                workbook1.sheetnames[columns[j]].write("B1","state")
                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                count.append(counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                 for k in range(0,i):
                        if data[k][j]==data[i][j]:
                            flag3=1
                            #print(data[i][j])
                            #print(k)
                            #break
                            previous_counter=count[k]
                            #previous_count[i][j]=previous_counter
                            print(data[i][j],'-',previous_counter)
                            break
                 if flag3==0:
                    
                    print(data[i][j],'-',counter)
                    #print(data[i][j],'-',temp)
                    workbook1.sheetnames[columns[j]].write("A1","sEth")
                    workbook1.sheetnames[columns[j]].write("B1","state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                    count.append(counter)
                    previous_counter=counter
                    #previous_count[i][j]=previous_counter
                    counter=counter+1
                    temp=counter
        elif j==length-1:
            print(previous_counter,'-',data[i][j])
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1","Action")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            #n=n+1
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            temp=previous_counter+1
            #o=o+1
            #counter=counter+1
        elif j==1:
            flag2=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count1.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp=counter
            else:
                
                for k in range(0,i):
                    #print("previous value",data[k][j])
                    if data[k][j]==data[i][j]: 
                        flag2=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count[k]==previous_counter:
                            counter=count1[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            break
                        elif previous_count[k]!=previous_counter:
                            #count_max=max(temp,counter)
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',count_max)
                            previous_count.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count1.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                #for k in range(0,i):
                if flag2==0:
                    
                    #print(data[k][j])
                        #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)
                        
                        #print(data[i][j])
                    count_max=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    #print(previous_counter,'-',data[i][j],'-',temp)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count1.append(counter)
                    previous_counter=counter
                    counter=counter+1
                            #temp=counter
                            #previous_count[i][j]=previous_counter
        elif j==2:
            flag1=0
            f=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count1.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count2.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp=counter
            else:
                
                for k in range(0,i):
                    #print("previous value",data[k][j])
                    if data[k][j]==data[i][j]: 
                        flag1=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count1[k]==previous_counter:
                            f=1
                            counter=count2[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            break
                        #elif previous_count1[k]!=previous_counter:
                if f==0:
                    print(previous_counter,'-',data[i][j],'-',counter)
                    #print(previous_counter,'-',data[i][j],'-',temp)
                    previous_count1.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                    count2.append(counter)
                    previous_counter=counter
                    #previous_count[i][j]=previous_counter
                    counter=counter+1
                            #temp=counter
                    #for k in range(0,i):
                if flag1==0:
                    #print(data[k][j])
                        #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)
                        
                        #print(data[i][j])
                    #counter=temp
                    count_max=max(temp,counter)
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count1.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count2.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
                    #temp=counter
                    #counter=counter+1
        elif j==3:
            flag=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count2.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count3.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count2[k]==previous_counter:
                            counter=count3[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count2[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count2.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count3.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count2.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count3.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==4:
            flag4=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count3.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count4.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag4=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count3[k]==previous_counter:
                            counter=count4[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count3[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count3.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count4.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag4==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count3.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count4.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==5:
            flag5=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count4.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count5.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag5=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count4[k]==previous_counter:
                            counter=count5[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count4[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count4.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count5.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            break
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag5==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count4.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count5.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==6:
            flag6=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count5.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count6.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag6=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count5[k]==previous_counter:
                            counter=count6[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count5[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count5.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count6.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            break
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag6==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count5.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count6.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
        elif j==7:
            flag7=0
            if i==0:
                print(previous_counter,'-',data[i][j],'-',counter)
                #print(previous_counter,'-',data[i][j],'-',temp)
                previous_count6.append(previous_counter)
                #outsheetj.write("A1","Previous_state")
                #outsheetj.write("B1",columns[j])
                #outsheetj.write("C1","next_state")
                #outsheetj.write(i+1,0,previous_counter)
                #outsheetj.write(i+1,1,data[i][j])
                #outsheetj.write(i+1,2,counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                #sheet_name1.write()
                #sheet_name=columns[j]
                #print(column[j])
                #worksheet=outworkbook.add_worksheet(sheet_name)
                count7.append(counter)
                previous_counter=counter
                counter=counter+1
                #temp
            else:
                
                for k in range(0,i):
                    
                    if data[k][j]==data[i][j]: 
                        #print("matching loop")
                        flag7=1
                        #print("current value",data[i][j])
                        #print("previous counter-",previous_counter)
                        #print("previous counter-",previous_counter)
                        if previous_count6[k]==previous_counter:
                            counter=count7[k]
                            print(previous_counter,'-',data[i][j],'-',counter)
                            previous_counter=counter
                            
                            break
                        elif previous_count6[k]!=previous_counter:
                            print(previous_counter,'-',data[i][j],'-',counter)
                            #print(previous_counter,'-',data[i][j],'-',temp)
                            previous_count6.append(previous_counter)
                            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                            workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                            workbook1.sheetnames[columns[j]].write("C1","next_state")
                            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                            workbook1.sheetnames[columns[j]].write(i+1,2,counter)                      
                            count7.append(counter)
                            previous_counter=counter
                            #previous_count[i][j]=previous_counter
                            counter=counter+1
                            break
                            #temp=counter
                            #break
                    #for k in range(0,i):
                if flag7==0:
                    #print("not matching loop")
                    #print(data[k][j])
                    #if data[k][j]!=data[i][j]:
                        #print("previous counter+",previous_counter)

                    count_max=max(temp,counter)
                    #print(data[i][j])
                    #counter=temp
                    #print(previous_counter,'-',data[i][j],'-',counter)
                    print(previous_counter,'-',data[i][j],'-',count_max)
                    previous_count6.append(previous_counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,count_max)                      
                    count7.append(counter)
                    #previous_counter=counter
                    previous_counter=count_max
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=count_max+1
# Out:
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - s1b.time.edu.cn - 4
# 4 - dcape-na.amazon.com - 5
# 5 - 17 - 6
# 6 - 123 - 7
# 7 - 443 - 8
# 8 - forward
# * - 9
# 9 - 9e:8d:de:80:29:28 - 10
# 9 - 9e:8d:de:80:29:28 - 10
# 10 - 0x0800 - 11
# 11 - fr.pool.ntp.org - 12
# 12 - softwareupdates.amazon.com - 13
# 13 - 17 - 14
# 14 - 123 - 15
# 15 - 80 - 16
# 16 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - de.pool.ntp.org - 17
# 17 - 3.north-america.pool.ntp.org - 18
# 18 - 17 - 19
# 19 - 123 - 20
# 20 - 53 - 21
# 21 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0006 - 2
# 2 - 0x0006 - 22
# 22 - us.pool.ntp.org - 23
# 23 - 224.0.0.22/32 - 24
# 24 - 17 - 25
# 25 - 123 - 26
# 26 - 67 - 27
# 27 - forward
# * - 9
# 9 - 9e:8d:de:80:29:28 - 10
# 10 - 0x0800 - 11
# 11 - ca.pool.ntp.org - 28
# 28 - 239.255.255.250/32 - 29
# 29 - 17 - 30
# 30 - 123 - 31
# 31 - 33434 - 32
# 32 - forward
