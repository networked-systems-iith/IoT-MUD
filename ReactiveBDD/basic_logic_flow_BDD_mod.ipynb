# %%
import pandas as pd
import json
import glob
import os       
import xlsxwriter

# %%
df1 = pd.read_csv(r'E:/PhD/json/all_device1.csv')

# %%
print(df1)
# Out:
#                    sEth               dEth  typEth proto sPort dPort  \
# 0     9e:8d:de:80:29:28                  *  0x0800     6     *   443
# 1     9e:8d:de:80:29:28                  *  0x0800     6     *   443
# 2     9e:8d:de:80:29:28                  *  0x0800    17     *   123
# 3     9e:8d:de:80:29:28                  *       *     2     *     *
# 4     9e:8d:de:80:29:28                  *  0x0800    17     *  1900
# ...                 ...                ...     ...   ...   ...   ...
# 1020                  *                  *  0x0800    17    53     *
# 1021                  *  9e:8d:de:80:29:28  0x0800     6   443     *
# 1022                  *                  *  0x0800    17    67     *
# 1023                  *  9e:8d:de:80:29:28  0x0800     6    80     *
# 1024                  *                  *  0x888e     *     *     *
#
#                     Source                   Destination   action
# 0                        *           dcape-na.amazon.com  forward
# 1                        *    softwareupdates.amazon.com  forward
# 2                        *  3.north-america.pool.ntp.org  forward
# 3                        *                 224.0.0.22/32  forward
# 4                        *            239.255.255.250/32  forward
# ...                    ...                           ...      ...
# 1020                     *                             *  forward
# 1021  scalews.withings.net                             *  forward
# 1022                     *                             *  forward
# 1023  scalews.withings.net                             *  forward
# 1024                     *                             *  forward
#
# [1025 rows x 9 columns]

# %%
data=df1.values.tolist()
print(data)
# Out:
# [['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '443', '*', 'dcape-na.amazon.com', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '443', '*', 'softwareupdates.amazon.com', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '17', '*', '123', '*', '3.north-america.pool.ntp.org', 'forward'], ['9e:8d:de:80:29:28', '*', '*', '2', '*', '*', '*', '224.0.0.22/32', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '17', '*', '1900', '*', '239.255.255.250/32', 'forward'], ['9e:8d:de:80:29:28', 'ff:ff:ff:ff:ff:ff', '0x0800', '17', '*', '67', '*', '255.255.255.255/32', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '17', '*', '123', '*', 'ntp-g7g.amazon.com', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '443', '*', 'todo-ta-g7g.amazon.com', 'forward'], ['*', '*', '0x0800', '1', '*', '*', '*', '*', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '80', '*', 'www.example.org', 'forward'], ['*', '*', '0x0800', '17', '*', '53', '*', '*', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '443', '*', 'pindorama-us-west-2.amazon.com', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '443', '*', 'tinytts-us-west-2.amazon.com', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '17', '*', '53', '*', '208.67.220.220/32', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '443', '*', 'device-fingerprintdb-v1.s3.amazonaws.com', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '443', '*', 'api.amazonalexa.com', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '80', '*', 'www.example.com', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '17', '*', '123', '*', '1.north-america.pool.ntp.org', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '443', '*', 'www.meethue.com', 'forward'], ['*', '*', '0x0800', '17', '*', '67', '*', '*', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '17', '*', '123', '*', '2.north-america.pool.ntp.org', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '80', '*', 'kindle-time.amazon.com', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '443', '*', 'device-metrics-us.amazon.com', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '443', '*', 'files.whooshkaa.com', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '17', '*', '5353', '*', '224.0.0.251/32', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '17', '*', '33434', '*', 'pins.amazon.com', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '443', '*', 'media.whooshkaa.com', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '17', '*', '123', '*', '0.north-america.pool.ntp.org', 'forward'], ['9e:8d:de:80:29:28', '*', '0x0800', '6', '*', '80', '*', 'www.example.net', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', '17', '123', '*', '3.north-america.pool.ntp.org', '*', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', '17', '123', '*', 'ntp-g7g.amazon.com', '*', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', '6', '443', '*', 'api.amazonalexa.com', '*', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', '6', '443', '*', 'tinytts-us-west-2.amazon.com', '*', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', '17', '123', '*', '2.north-america.pool.ntp.org', '*', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', '6', '443', '*', 'todo-ta-g7g.amazon.com', '*', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', '17', '123', '*', '1.north-america.pool.ntp.org', '*', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', '17', '123', '*', '0.north-america.pool.ntp.org', '*', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', '6', '80', '*', 'www.example.com', '*', 'forward'], ['*', '*', '0x0800', '17', '67', '*', '*', '*', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', '17', '53', '*', '208.67.220.220/32', '*', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', '6', '443', '*', 'device-metrics-us.amazon.com', '*', 'forward'], ['*', '*', '0x0800', '1', '*', '*', '*', '*', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', '6', '443', '*', 'device-fingerprintdb-v1.s3.amazonaws ...

# %%
columns=df1.columns

# %%
length=len(data[0])

# %%
workbook1=xlsxwriter.Workbook("output_delete.xlsx")

# %%
workbook1=xlsxwriter.Workbook("output_test.xlsx")

# %%
workbook1=xlsxwriter.Workbook("output_test1.xlsx")

# %%
workbook1=xlsxwriter.Workbook("output_all_rules.xlsx")

# %%
for j in range(0,length):
    outsheet=workbook1.add_worksheet(columns[j])

# %%
workbook1.sheetnames
# Out:
# {'sEth': <xlsxwriter.worksheet.Worksheet at 0x44ed0a0>,
#  'dEth': <xlsxwriter.worksheet.Worksheet at 0x44ed190>,
#  'typEth': <xlsxwriter.worksheet.Worksheet at 0x44ed1c0>,
#  'proto': <xlsxwriter.worksheet.Worksheet at 0x44ed1d8>,
#  'sPort': <xlsxwriter.worksheet.Worksheet at 0x44ed208>,
#  'dPort': <xlsxwriter.worksheet.Worksheet at 0x44ed148>,
#  'Source': <xlsxwriter.worksheet.Worksheet at 0x44ed160>,
#  'Destination': <xlsxwriter.worksheet.Worksheet at 0x44ed118>,
#  'action': <xlsxwriter.worksheet.Worksheet at 0x44ed130>}

# %%
counter=1
counter1=0
count=[]
count1=[]
count2=[]
count3=[]
count4=[]
count5=[]
count6=[]
count7=[]
previous_count=[]
previous_count1=[]
previous_count2=[]
previous_count3=[]
previous_count4=[]
previous_count5=[]
previous_count6=[]
for i in range(len(data)) :
    length=len(data[i])
    for j in range(len(data[i])) :
        if j==0:
            flag=0
            if i==0:
                print(data[i][j],'-',counter)
                #print(data[i][j],'-',temp)
                workbook1.sheetnames[columns[j]].write("A1","sEth")
                workbook1.sheetnames[columns[j]].write("B1","state")
                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                count.append(counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print("for loop")
                    if data[k][j]==data[i][j]:
                        #print("IF loop")
                        flag=1
                        #var=k
                        previous_counter=count[k]
                        count.append(counter)
                        print(data[i][j],'-',previous_counter)
                        break
                        
                if flag==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(data[i][j],'-',counter)
                    #print(data[i][j],'-',temp)
                    workbook1.sheetnames[columns[j]].write("A1","sEth")
                    workbook1.sheetnames[columns[j]].write("B1","state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                    count.append(counter)
                    #previous_counter=counter
                    previous_counter=counter
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=counter+1
                    #temp=counter
        elif j==length-1:
            print(previous_counter,'-',data[i][j])
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1","Action")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            #n=n+1
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            temp=previous_counter+1
        elif j==1:
            flag1=0
            f1=0
            #f=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count1.append(counter)
                previous_count.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count[k]==previous_counter:
                        flag1=1
                        counter=count1[k]
                        count1.append(counter)  
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count.append(previous_counter)
                        f1=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count[k]!=previous_counter:
                        flag1=1
                        f1=2
                            
                if f1==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count.append(previous_counter)
                    count1.append(counter)
                    previous_counter=counter
                        #previous_count[i][j]=previous_counter
                    counter=counter+1
                if flag1==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count1.append(counter)
                    #print(count1)
                    previous_count.append(previous_counter)
                    #print(previous_count)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
        elif j==2:
            flag2=0
            f=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count2.append(counter)
                previous_count1.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print(k)
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count1[k]==previous_counter:
                        #print("IF loop")
                        flag2=1
                        f=1
                        #if previous_count1[k]==previous_counter:
                        counter=count2[k]
                        count2.append(counter)
                        #print(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count1.append(previous_counter)
                            #f=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count1[k]!=previous_counter:
                        flag2=1
                        f=2
                if f==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count1.append(previous_counter)
                    count2.append(counter)
                    previous_counter=counter
                            #previous_count[i][j]=previous_counter
                    counter=counter+1
                    
                if flag2==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count2.append(counter)
                    #print(count2)
                    previous_count1.append(previous_counter)
                   # print(previous_count1)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
        elif j==3:
            flag3=0
            f2=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count3.append(counter)
                previous_count2.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print(k)
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count2[k]==previous_counter:
                        #print("IF loop")
                        flag3=1
                        f2=1
                        #if previous_count1[k]==previous_counter:
                        counter=count3[k]
                        count3.append(counter)
                        #print(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count2.append(previous_counter)
                            #f=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count2[k]!=previous_counter:
                        flag3=1
                        f2=2
                if f2==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count2.append(previous_counter)
                    count3.append(counter)
                    previous_counter=counter
                            #previous_count[i][j]=previous_counter
                    counter=counter+1
                    
                if flag3==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count3.append(counter)
                    #print(count2)
                    previous_count2.append(previous_counter)
                   # print(previous_count1)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
        elif j==4:
            flag4=0
            f3=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count4.append(counter)
                previous_count3.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print(k)
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count3[k]==previous_counter:
                        #print("IF loop")
                        flag4=1
                        f3=1
                        #if previous_count1[k]==previous_counter:
                        counter=count4[k]
                        count4.append(counter)
                        #print(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count3.append(previous_counter)
                            #f=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count3[k]!=previous_counter:
                        flag4=1
                        f3=2
                if f3==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count3.append(previous_counter)
                    count4.append(counter)
                    previous_counter=counter
                            #previous_count[i][j]=previous_counter
                    counter=counter+1
                    
                if flag4==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count4.append(counter)
                    #print(count2)
                    previous_count3.append(previous_counter)
                   # print(previous_count1)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
        elif j==5:
            flag5=0
            f4=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count5.append(counter)
                previous_count4.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print(k)
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count4[k]==previous_counter:
                        #print("IF loop")
                        flag5=1
                        f4=1
                        #if previous_count1[k]==previous_counter:
                        counter=count5[k]
                        count5.append(counter)
                        #print(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count4.append(previous_counter)
                            #f=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count4[k]!=previous_counter:
                        flag5=1
                        f4=2
                if f4==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count4.append(previous_counter)
                    count5.append(counter)
                    previous_counter=counter
                            #previous_count[i][j]=previous_counter
                    counter=counter+1
                    
                if flag5==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count5.append(counter)
                    #print(count2)
                    previous_count4.append(previous_counter)
                   # print(previous_count1)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
        elif j==6:
            flag6=0
            f5=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count6.append(counter)
                previous_count5.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print(k)
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count5[k]==previous_counter:
                        #print("IF loop")
                        flag6=1
                        f5=1
                        #if previous_count1[k]==previous_counter:
                        counter=count6[k]
                        count6.append(counter)
                        #print(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count5.append(previous_counter)
                            #f=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count5[k]!=previous_counter:
                        flag6=1
                        f5=2
                if f5==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count5.append(previous_counter)
                    count6.append(counter)
                    previous_counter=counter
                            #previous_count[i][j]=previous_counter
                    counter=counter+1
                    
                if flag6==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count6.append(counter)
                    #print(count2)
                    previous_count5.append(previous_counter)
                   # print(previous_count1)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
        elif j==7:
            flag7=0
            f6=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count7.append(counter)
                previous_count6.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print(k)
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count6[k]==previous_counter:
                        #print("IF loop")
                        flag7=1
                        f6=1
                        #if previous_count1[k]==previous_counter:
                        counter=count7[k]
                        count7.append(counter)
                        #print(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count6.append(previous_counter)
                            #f=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count6[k]!=previous_counter:
                        flag7=1
                        f6=2
                if f6==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count6.append(previous_counter)
                    count7.append(counter)
                    previous_counter=counter
                            #previous_count[i][j]=previous_counter
                    counter=counter+1
                    
                if flag7==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count7.append(counter)
                    #print(count2)
                    previous_count6.append(previous_counter)
                   # print(previous_count1)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
# Out:
# 9e:8d:de:80:29:28 - 1
# 1 * - 2
# 2 0x0800 - 3
# 3 6 - 4
# 4 * - 5
# 5 443 - 6
# 6 * - 7
# 7 dcape-na.amazon.com - 8
# 8 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - softwareupdates.amazon.com - 9
# 9 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 123 - 12
# 12 - * - 13
# 13 - 3.north-america.pool.ntp.org - 14
# 14 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 15
# 15 - 2 - 16
# 16 - * - 17
# 17 - * - 18
# 18 - * - 19
# 19 - 224.0.0.22/32 - 20
# 20 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 1900 - 21
# 21 - * - 22
# 22 - 239.255.255.250/32 - 23
# 23 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 24
# 24 - 0x0800 - 25
# 25 - 17 - 26
# 26 - * - 27
# 27 - 67 - 28
# 28 - * - 29
# 29 - 255.255.255.255/32 - 30
# 30 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 123 - 12
# 12 - * - 13
# 13 - ntp-g7g.amazon.com - 31
# 31 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - todo-ta-g7g.amazon.com - 32
# 32 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 1 - 36
# 36 - * - 37
# 37 - * - 38
# 38 - * - 39
# 39 - * - 40
# 40 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - www.example.org - 43
# 43 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 53 - 46
# 46 - * - 47
# 47 - * - 48
# 48 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - pindorama-us-west-2.amazon.com - 49
# 49 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - tinytts-us-west-2.amazon.com - 50
# 50 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 53 - 51
# 51 - * - 52
# 52 - 208.67.220.220/32 - 53
# 53 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - device-fingerprintdb-v1.s3.amazonaws.com - 54
# 54 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - api.amazonalexa.com - 55
# 55 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - www.example.com - 56
# 56 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 123 - 12
# 12 - * - 13
# 13 - 1.north-america.pool.ntp.org - 57
# 57 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - www.meethue.com - 58
# 58 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 67 - 59
# 59 - * - 60
# 60 - * - 61
# 61 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 123 - 12
# 12 - * - 13
# 13 - 2.north-america.pool.ntp.org - 62
# 62 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - kindle-time.amazon.com - 63
# 63 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - device-metrics-us.amazon.com - 64
# 64 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - files.whooshkaa.com - 65
# 65 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 5353 - 66
# 66 - * - 67
# 67 - 224.0.0.251/32 - 68
# 68 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 33434 - 69
# 69 - * - 70
# 70 - pins.amazon.com - 71
# 71 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - media.whooshkaa.com - 72
# 72 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 123 - 12
# 12 - * - 13
# 13 - 0.north-america.pool.ntp.org - 73
# 73 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - www.example.net - 74
# 74 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 123 - 78
# 78 - * - 79
# 79 - 3.north-america.pool.ntp.org - 80
# 80 - * - 81
# 81 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 123 - 78
# 78 - * - 79
# 79 - ntp-g7g.amazon.com - 82
# 82 - * - 83
# 83 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - api.amazonalexa.com - 87
# 87 - * - 88
# 88 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - tinytts-us-west-2.amazon.com - 89
# 89 - * - 90
# 90 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 123 - 78
# 78 - * - 79
# 79 - 2.north-america.pool.ntp.org - 91
# 91 - * - 92
# 92 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - todo-ta-g7g.amazon.com - 93
# 93 - * - 94
# 94 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 123 - 78
# 78 - * - 79
# 79 - 1.north-america.pool.ntp.org - 95
# 95 - * - 96
# 96 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 123 - 78
# 78 - * - 79
# 79 - 0.north-america.pool.ntp.org - 97
# 97 - * - 98
# 98 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - www.example.com - 101
# 101 - * - 102
# 102 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 67 - 103
# 103 - * - 104
# 104 - * - 105
# 105 - * - 106
# 106 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 53 - 107
# 107 - * - 108
# 108 - 208.67.220.220/32 - 109
# 109 - * - 110
# 110 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - device-metrics-us.amazon.com - 111
# 111 - * - 112
# 112 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 1 - 36
# 36 - * - 37
# 37 - * - 38
# 38 - * - 39
# 39 - * - 40
# 40 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - device-fingerprintdb-v1.s3.amazonaws.com - 86
# 86 - * - 87
# 87 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 53 - 88
# 88 - * - 89
# 89 - * - 90
# 90 - * - 91
# 91 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - dcape-na.amazon.com - 92
# 92 - * - 93
# 93 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - www.meethue.com - 94
# 94 - * - 95
# 95 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - files.whooshkaa.com - 96
# 96 - * - 97
# 97 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 33434 - 98
# 98 - * - 99
# 99 - pins.amazon.com - 100
# 100 - * - 101
# 101 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - kindle-time.amazon.com - 102
# 102 - * - 103
# 103 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - media.whooshkaa.com - 104
# 104 - * - 105
# 105 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - softwareupdates.amazon.com - 106
# 106 - * - 107
# 107 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - www.example.net - 108
# 108 - * - 109
# 109 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 50000 - 110
# 110 - * - 111
# 111 - * - 112
# 112 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - www.example.org - 113
# 113 - * - 114
# 114 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - pindorama-us-west-2.amazon.com - 115
# 115 - * - 116
# 116 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0006 - 117
# 117 - * - 118
# 118 - * - 119
# 119 - * - 120
# 120 - * - 121
# 121 - * - 122
# 122 - forward
# * - 33
# 33 - * - 34
# 34 - 0x888e - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - 336971aac5bba454b967-3ec27f5c732731b07836c69a45967ad6.ssl.cf1.rackcdn.com - 129
# 129 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 24
# 24 - 0x0800 - 25
# 25 - 17 - 26
# 26 - * - 27
# 27 - 67 - 28
# 28 - * - 29
# 29 - 255.255.255.255/32 - 30
# 30 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - rpsv2.video-cloud.net - 31
# 31 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - iconfig.august.com - 32
# 32 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 53 - 46
# 46 - * - 47
# 47 - * - 48
# 48 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - rpsv12.video-cloud.net - 49
# 49 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - vcsv2.video-cloud.net - 50
# 50 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - 8.8.4.4/32 - 55
# 55 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - rpsv3.video-cloud.net - 56
# 56 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - doorbells.august.com - 57
# 57 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - rpsv7.video-cloud.net - 58
# 58 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - v2servers.video-cloud.net - 59
# 59 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 53 - 51
# 51 - * - 52
# 52 - 8.8.8.8/32 - 60
# 60 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 67 - 59
# 59 - * - 60
# 60 - * - 61
# 61 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - rpsv11.video-cloud.net - 62
# 62 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - rpsv222.video-cloud.net - 63
# 63 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - august.pubnub.com - 64
# 64 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - logger.august.com - 65
# 65 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - s3-us-west-2.amazonaws.com - 66
# 66 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - rpsv4.video-cloud.net - 67
# 67 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - doorbells.august.com - 68
# 68 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - rbs-sticky.august.com - 69
# 69 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - rpsv1.video-cloud.net - 70
# 70 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - rpsv10.video-cloud.net - 71
# 71 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - rpsv5.video-cloud.net - 72
# 72 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - dmsv2.video-cloud.net - 73
# 73 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - 8.8.8.8/32 - 74
# 74 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - rpsv7.video-cloud.net - 86
# 86 - * - 87
# 87 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - august.pubnub.com - 88
# 88 - * - 89
# 89 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - rpsv2.video-cloud.net - 90
# 90 - * - 91
# 91 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - s3-us-west-2.amazonaws.com - 92
# 92 - * - 93
# 93 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - logger.august.com - 94
# 94 - * - 95
# 95 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - 336971aac5bba454b967-3ec27f5c732731b07836c69a45967ad6.ssl.cf1.rackcdn.com - 96
# 96 - * - 97
# 97 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - rpsv11.video-cloud.net - 98
# 98 - * - 99
# 99 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - dmsv2.video-cloud.net - 100
# 100 - * - 101
# 101 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 67 - 103
# 103 - * - 104
# 104 - * - 105
# 105 - * - 106
# 106 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 1 - 107
# 107 - * - 108
# 108 - * - 109
# 109 - doorbells.august.com - 110
# 110 - * - 111
# 111 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 53 - 107
# 107 - * - 108
# 108 - 8.8.8.8/32 - 112
# 112 - * - 112
# 112 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - rpsv1.video-cloud.net - 113
# 113 - * - 114
# 114 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - rpsv4.video-cloud.net - 115
# 115 - * - 116
# 116 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - rpsv3.video-cloud.net - 117
# 117 - * - 118
# 118 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 53 - 88
# 88 - * - 89
# 89 - * - 90
# 90 - * - 91
# 91 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - v2servers.video-cloud.net - 92
# 92 - * - 93
# 93 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - iconfig.august.com - 94
# 94 - * - 95
# 95 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - rpsv222.video-cloud.net - 96
# 96 - * - 97
# 97 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - rpsv10.video-cloud.net - 98
# 98 - * - 99
# 99 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - doorbells.august.com - 100
# 100 - * - 101
# 101 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - vcsv2.video-cloud.net - 102
# 102 - * - 103
# 103 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - rpsv5.video-cloud.net - 104
# 104 - * - 105
# 105 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 1 - 107
# 107 - * - 108
# 108 - * - 109
# 109 - 8.8.8.8/32 - 109
# 109 - * - 110
# 110 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 1 - 107
# 107 - * - 108
# 108 - * - 109
# 109 - 8.8.4.4/32 - 111
# 111 - * - 112
# 112 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - rbs-sticky.august.com - 113
# 113 - * - 114
# 114 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - rpsv12.video-cloud.net - 115
# 115 - * - 116
# 116 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 17 - 118
# 118 - * - 119
# 119 - 547 - 119
# 119 - * - 120
# 120 - * - 121
# 121 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 58 - 122
# 122 - * - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 58 - 122
# 122 - * - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 17 - 118
# 118 - * - 119
# 119 - 53 - 127
# 127 - * - 128
# 128 - * - 129
# 129 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 0 - 130
# 130 - * - 131
# 131 - * - 132
# 132 - * - 133
# 133 - * - 134
# 134 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 17 - 118
# 118 - * - 119
# 119 - 53 - 127
# 127 - * - 128
# 128 - * - 129
# 129 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 58 - 122
# 122 - * - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 17 - 118
# 118 - 547 - 127
# 127 - * - 128
# 128 - * - 128
# 128 - * - 129
# 129 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 17 - 118
# 118 - 53 - 130
# 130 - * - 131
# 131 - * - 132
# 132 - * - 133
# 133 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 17 - 118
# 118 - 53 - 130
# 130 - * - 131
# 131 - * - 132
# 132 - * - 133
# 133 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0006 - 117
# 117 - * - 118
# 118 - * - 119
# 119 - * - 120
# 120 - * - 121
# 121 - * - 122
# 122 - forward
# * - 33
# 33 - * - 34
# 34 - 0x888e - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 67 - 59
# 59 - * - 60
# 60 - * - 61
# 61 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 53 - 46
# 46 - * - 47
# 47 - * - 48
# 48 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - ota.awair.is - 49
# 49 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - timeserver.awair.is - 50
# 50 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 24
# 24 - 0x0800 - 25
# 25 - 17 - 26
# 26 - * - 27
# 27 - 67 - 28
# 28 - * - 29
# 29 - 255.255.255.255/32 - 30
# 30 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 8883 - 31
# 31 - * - 32
# 32 - messaging.awair.is - 33
# 33 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 53 - 51
# 51 - * - 52
# 52 - 8.8.8.8/32 - 60
# 60 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 8883 - 84
# 84 - * - 85
# 85 - messaging.awair.is - 86
# 86 - * - 87
# 87 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 53 - 88
# 88 - * - 89
# 89 - * - 90
# 90 - * - 91
# 91 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - timeserver.awair.is - 92
# 92 - * - 93
# 93 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 67 - 103
# 103 - * - 104
# 104 - * - 105
# 105 - * - 106
# 106 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 53 - 107
# 107 - * - 108
# 108 - 8.8.8.8/32 - 112
# 112 - * - 112
# 112 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - ota.awair.is - 113
# 113 - * - 114
# 114 - forward
# * - 33
# 33 - * - 34
# 34 - 0x888e - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0006 - 117
# 117 - * - 118
# 118 - * - 119
# 119 - * - 120
# 120 - * - 121
# 121 - * - 122
# 122 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - origin.belkin-us.tendplatform.com - 123
# 123 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 8443 - 124
# 124 - * - 125
# 125 - api.xbcs.net - 125
# 125 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - * - 127
# 127 - 5104 - 128
# 128 - * - 128
# 128 - * - 129
# 129 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 67 - 59
# 59 - * - 60
# 60 - * - 61
# 61 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 1900 - 21
# 21 - * - 22
# 22 - 239.255.255.250/32 - 23
# 23 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - * - 127
# 127 - 3478 - 127
# 127 - * - 128
# 128 - * - 129
# 129 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 1 - 36
# 36 - * - 37
# 37 - * - 38
# 38 - * - 39
# 39 - * - 40
# 40 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - ping.seedonk.com - 54
# 54 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 3475 - 55
# 55 - * - 56
# 56 - prod1-nat-xbcs-net-1543133972.us-east-1.elb.amazonaws.com - 57
# 57 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 8899 - 58
# 58 - * - 59
# 59 - devices.xbcs.net - 60
# 60 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - 9207 - 126
# 126 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 123 - 12
# 12 - * - 13
# 13 - time.windows.com - 129
# 129 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 15
# 15 - 2 - 16
# 16 - * - 17
# 17 - * - 18
# 18 - * - 19
# 19 - 239.255.255.250/32 - 130
# 130 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 53 - 46
# 46 - * - 47
# 47 - * - 48
# 48 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 5104 - 49
# 49 - * - 50
# 50 - origin.belkin-us.tendplatform.com - 51
# 51 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - 49154 - 126
# 126 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - * - 129
# 129 - * - 130
# 130 - * - 131
# 131 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 3475 - 55
# 55 - * - 56
# 56 - nat.xbcs.net - 132
# 132 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 15
# 15 - 2 - 16
# 16 - * - 17
# 17 - * - 18
# 18 - * - 19
# 19 - 224.0.0.2/32 - 133
# 133 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - www.google.com - 134
# 134 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 53 - 51
# 51 - * - 52
# 52 - 8.8.8.8/32 - 60
# 60 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - 49153 - 126
# 126 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 1 - 107
# 107 - * - 108
# 108 - * - 109
# 109 - ping.seedonk.com - 129
# 129 - * - 129
# 129 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 1 - 36
# 36 - * - 37
# 37 - * - 38
# 38 - * - 39
# 39 - * - 40
# 40 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - origin.belkin-us.tendplatform.com - 86
# 86 - * - 87
# 87 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 53 - 88
# 88 - * - 89
# 89 - * - 90
# 90 - * - 91
# 91 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 5104 - 92
# 92 - * - 93
# 93 - origin.belkin-us.tendplatform.com - 94
# 94 - * - 95
# 95 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - * - 127
# 127 - 49153 - 127
# 127 - * - 128
# 128 - * - 129
# 129 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 8899 - 130
# 130 - * - 131
# 131 - devices.xbcs.net - 131
# 131 - * - 132
# 132 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - * - 127
# 127 - 9207 - 133
# 133 - * - 134
# 134 - * - 135
# 135 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 123 - 78
# 78 - * - 79
# 79 - time.windows.com - 136
# 136 - * - 137
# 137 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - * - 127
# 127 - 49154 - 138
# 138 - * - 139
# 139 - * - 140
# 140 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - * - 129
# 129 - * - 130
# 130 - * - 131
# 131 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 1 - 107
# 107 - * - 108
# 108 - * - 109
# 109 - www.google.com - 132
# 132 - * - 133
# 133 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 67 - 103
# 103 - * - 104
# 104 - * - 105
# 105 - * - 106
# 106 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - 5104 - 126
# 126 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 53 - 107
# 107 - * - 108
# 108 - 8.8.8.8/32 - 112
# 112 - * - 112
# 112 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 3475 - 113
# 113 - * - 114
# 114 - prod1-nat-xbcs-net-1543133972.us-east-1.elb.amazonaws.com - 115
# 115 - * - 116
# 116 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - 3478 - 126
# 126 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 3475 - 113
# 113 - * - 114
# 114 - nat.xbcs.net - 129
# 129 - * - 129
# 129 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 8443 - 130
# 130 - * - 131
# 131 - api.xbcs.net - 131
# 131 - * - 132
# 132 - forward
# * - 33
# 33 - * - 34
# 34 - 0x888e - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0006 - 117
# 117 - * - 118
# 118 - * - 119
# 119 - * - 120
# 120 - * - 121
# 121 - * - 122
# 122 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 15
# 15 - 2 - 16
# 16 - * - 17
# 17 - * - 18
# 18 - * - 19
# 19 - 224.0.0.1/32 - 123
# 123 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 8777 - 124
# 124 - * - 125
# 125 - tech.carematix.com - 125
# 125 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 53 - 46
# 46 - * - 47
# 47 - * - 48
# 48 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 24
# 24 - 0x0800 - 25
# 25 - 17 - 26
# 26 - * - 27
# 27 - 67 - 28
# 28 - * - 29
# 29 - 255.255.255.255/32 - 30
# 30 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 53 - 88
# 88 - * - 89
# 89 - * - 90
# 90 - * - 91
# 91 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 8777 - 92
# 92 - * - 93
# 93 - tech.carematix.com - 93
# 93 - * - 94
# 94 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 67 - 103
# 103 - * - 104
# 104 - * - 105
# 105 - * - 106
# 106 - forward
# * - 33
# 33 - * - 34
# 34 - 0x888e - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0006 - 117
# 117 - * - 118
# 118 - * - 119
# 119 - * - 120
# 120 - * - 121
# 121 - * - 122
# 122 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 67 - 59
# 59 - * - 60
# 60 - * - 61
# 61 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - h.canaryis.com - 62
# 62 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - m.canaryis.com - 63
# 63 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 24
# 24 - 0x0800 - 25
# 25 - 17 - 26
# 26 - * - 27
# 27 - 67 - 28
# 28 - * - 29
# 29 - 255.255.255.255/32 - 30
# 30 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - ipv4.connman.net - 42
# 42 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - b.canaryis.com - 43
# 43 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - 09-wl2-d-prod.canaryis.com - 44
# 44 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - v.canaryis.com - 45
# 45 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - o.canaryis.com - 46
# 46 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - i.canaryis.com - 47
# 47 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 53 - 46
# 46 - * - 47
# 47 - * - 48
# 48 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - i.canaryis.com - 49
# 49 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - h.canaryis.com - 50
# 50 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - i.canaryis.com - 86
# 86 - * - 87
# 87 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - b.canaryis.com - 88
# 88 - * - 89
# 89 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - i.canaryis.com - 100
# 100 - * - 101
# 101 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - 09-wl2-d-prod.canaryis.com - 102
# 102 - * - 103
# 103 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - h.canaryis.com - 104
# 104 - * - 105
# 105 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 53 - 88
# 88 - * - 89
# 89 - * - 90
# 90 - * - 91
# 91 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - o.canaryis.com - 92
# 92 - * - 93
# 93 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - h.canaryis.com - 94
# 94 - * - 95
# 95 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - ipv4.connman.net - 100
# 100 - * - 101
# 101 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 67 - 103
# 103 - * - 104
# 104 - * - 105
# 105 - * - 106
# 106 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - v.canaryis.com - 107
# 107 - * - 108
# 108 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - m.canaryis.com - 109
# 109 - * - 110
# 110 - forward
# * - 33
# 33 - * - 34
# 34 - 0x888e - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0006 - 117
# 117 - * - 118
# 118 - * - 119
# 119 - * - 120
# 120 - * - 121
# 121 - * - 122
# 122 - forward
# * - 33
# 33 - * - 34
# 34 - 0x888e - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0006 - 117
# 117 - * - 118
# 118 - * - 119
# 119 - * - 120
# 120 - * - 121
# 121 - * - 122
# 122 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - ad.doubleclick.net - 123
# 123 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 15
# 15 - 2 - 16
# 16 - * - 17
# 17 - * - 18
# 18 - * - 19
# 19 - 224.0.0.251/32 - 124
# 124 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - pagead2.googlesyndication.com - 125
# 125 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - www.googleapis.com - 126
# 126 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - ajax.googleapis.com - 127
# 127 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 53 - 46
# 46 - * - 47
# 47 - * - 48
# 48 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - storage.googleapis.com - 49
# 49 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - googleads.g.doubleclick.net - 50
# 50 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - tools.google.com - 125
# 125 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - 8009 - 126
# 126 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - r1---sn-55goxu-ntqe.googlevideo.com - 129
# 129 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 53 - 51
# 51 - * - 52
# 52 - 8.8.8.8/32 - 60
# 60 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - android.clients.google.com - 61
# 61 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - yt3.ggpht.com - 62
# 62 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - www.youtube-nocookie.com - 125
# 125 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - ssl.gstatic.com - 126
# 126 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - google.com - 127
# 127 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - tools.google.com - 128
# 128 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - ad.doubleclick.net - 129
# 129 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - ssl.gstatic.com - 130
# 130 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 123 - 12
# 12 - * - 13
# 13 - time.google.com - 131
# 131 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - 8.8.8.8/32 - 74
# 74 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - fonts.googleapis.com - 75
# 75 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - clients4.google.com - 76
# 76 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - lh6.googleusercontent.com - 125
# 125 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - www.gstatic.com - 126
# 126 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - lh5.googleusercontent.com - 127
# 127 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 15
# 15 - 2 - 16
# 16 - * - 17
# 17 - * - 18
# 18 - * - 19
# 19 - 239.255.255.250/32 - 130
# 130 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - connectivitycheck.gstatic.com - 131
# 131 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - android.clients.google.com - 132
# 132 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - i.ytimg.com - 133
# 133 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - ade.googlesyndication.com - 134
# 134 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - clients2.google.com - 135
# 135 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - fonts.googleapis.com - 136
# 136 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - clients4.google.com - 137
# 137 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - fonts.gstatic.com - 138
# 138 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - lh3.googleusercontent.com - 139
# 139 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - fonts.gstatic.com - 140
# 140 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - www.youtube.com - 141
# 141 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - clients1.google.com - 142
# 142 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - www.gstatic.com - 143
# 143 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - google.com - 144
# 144 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - r2---sn-ntq7yned.googlevideo.com - 145
# 145 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - clients2.google.com - 146
# 146 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - r4---sn-ntqe6n76.googlevideo.com - 147
# 147 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - clients3.google.com - 148
# 148 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - tools.google.com - 149
# 149 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 15
# 15 - 2 - 16
# 16 - * - 17
# 17 - * - 18
# 18 - * - 19
# 19 - 224.0.0.22/32 - 20
# 20 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 1900 - 21
# 21 - * - 22
# 22 - 239.255.255.250/32 - 23
# 23 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 24
# 24 - 0x0800 - 25
# 25 - 17 - 26
# 26 - * - 27
# 27 - 67 - 28
# 28 - * - 29
# 29 - 255.255.255.255/32 - 30
# 30 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - clients3.google.com - 54
# 54 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - clients3.google.com - 125
# 125 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 5228 - 126
# 126 - * - 127
# 127 - mtalk.google.com - 127
# 127 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - storage.googleapis.com - 128
# 128 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - android.clients.google.com - 129
# 129 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - r3---sn-55goxu-ntqe.googlevideo.com - 130
# 130 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 1 - 36
# 36 - * - 37
# 37 - * - 38
# 38 - * - 39
# 39 - * - 40
# 40 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - lh4.googleusercontent.com - 125
# 125 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - clients1.google.com - 126
# 126 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - www.googleapis.com - 127
# 127 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - android.clients.google.com - 128
# 128 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - pagead2.googlesyndication.com - 129
# 129 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - google.com - 130
# 130 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - cdn.ravenjs.com - 131
# 131 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - www.gstatic.com - 132
# 132 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - www.youtube.com - 133
# 133 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - yt3.ggpht.com - 134
# 134 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - lh3.googleusercontent.com - 135
# 135 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - googleads.g.doubleclick.net - 136
# 136 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - google.com - 137
# 137 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - lh6.googleusercontent.com - 138
# 138 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 5353 - 66
# 66 - * - 67
# 67 - 224.0.0.251/32 - 68
# 68 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - fonts.gstatic.com - 69
# 69 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - clients4.google.com - 70
# 70 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - connectivitycheck.gstatic.com - 71
# 71 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - clients2.google.com - 125
# 125 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 15
# 15 - 2 - 16
# 16 - * - 17
# 17 - * - 18
# 18 - * - 19
# 19 - 224.0.0.2/32 - 133
# 133 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - r1---sn-55goxu-ntqe.googlevideo.com - 134
# 134 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - clients1.google.com - 135
# 135 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - ajax.googleapis.com - 136
# 136 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - clients1.google.com - 137
# 137 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - secure.insightexpressai.com - 138
# 138 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - cast.scdn.co - 139
# 139 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - securepubads.g.doubleclick.net - 140
# 140 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - tools.google.com - 141
# 141 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - clients4.google.com - 142
# 142 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - api-partner.spotify.com - 143
# 143 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - www.youtube.com - 144
# 144 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - www.youtube.com - 145
# 145 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - clients2.google.com - 146
# 146 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - ssl.gstatic.com - 147
# 147 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - ade.googlesyndication.com - 148
# 148 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 67 - 59
# 59 - * - 60
# 60 - * - 61
# 61 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - r4---sn-ntqe6n76.googlevideo.com - 62
# 62 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - clients3.google.com - 63
# 63 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - lh5.googleusercontent.com - 125
# 125 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - www.youtube-nocookie.com - 126
# 126 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - connectivitycheck.gstatic.com - 127
# 127 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - lh4.googleusercontent.com - 128
# 128 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - 8008 - 129
# 129 - * - 129
# 129 - * - 130
# 130 - * - 131
# 131 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - securepubads.g.doubleclick.net - 132
# 132 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 443 - 125
# 125 - * - 125
# 125 - i.ytimg.com - 133
# 133 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - ssl.gstatic.com - 134
# 134 - * - 135
# 135 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - cast.scdn.co - 136
# 136 - * - 137
# 137 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - www.youtube.com - 138
# 138 - * - 139
# 139 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - lh4.googleusercontent.com - 140
# 140 - * - 141
# 141 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 443 - 142
# 142 - * - 143
# 143 - android.clients.google.com - 144
# 144 - * - 145
# 145 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 443 - 142
# 142 - * - 143
# 143 - clients2.google.com - 146
# 146 - * - 147
# 147 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 443 - 142
# 142 - * - 143
# 143 - www.youtube-nocookie.com - 148
# 148 - * - 149
# 149 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - clients3.google.com - 150
# 150 - * - 151
# 151 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - clients3.google.com - 152
# 152 - * - 153
# 153 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 443 - 142
# 142 - * - 143
# 143 - r2---sn-ntq7yned.googlevideo.com - 154
# 154 - * - 155
# 155 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - www.gstatic.com - 156
# 156 - * - 157
# 157 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - googleads.g.doubleclick.net - 158
# 158 - * - 159
# 159 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 67 - 103
# 103 - * - 104
# 104 - * - 105
# 105 - * - 106
# 106 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 443 - 142
# 142 - * - 143
# 143 - clients3.google.com - 143
# 143 - * - 144
# 144 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - clients1.google.com - 145
# 145 - * - 146
# 146 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 53 - 107
# 107 - * - 108
# 108 - 8.8.8.8/32 - 112
# 112 - * - 112
# 112 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 443 - 142
# 142 - * - 143
# 143 - lh6.googleusercontent.com - 143
# 143 - * - 144
# 144 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 1 - 107
# 107 - * - 108
# 108 - * - 109
# 109 - clients1.google.com - 145
# 145 - * - 146
# 146 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - r4---sn-ntqe6n76.googlevideo.com - 147
# 147 - * - 148
# 148 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - tools.google.com - 149
# 149 - * - 150
# 150 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 1 - 36
# 36 - * - 37
# 37 - * - 38
# 38 - * - 39
# 39 - * - 40
# 40 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 443 - 142
# 142 - * - 143
# 143 - r1---sn-55goxu-ntqe.googlevideo.com - 143
# 143 - * - 144
# 144 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 443 - 142
# 142 - * - 143
# 143 - r4---sn-ntqe6n76.googlevideo.com - 145
# 145 - * - 146
# 146 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 53 - 88
# 88 - * - 89
# 89 - * - 90
# 90 - * - 91
# 91 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 1 - 107
# 107 - * - 108
# 108 - * - 109
# 109 - tools.google.com - 109
# 109 - * - 110
# 110 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 443 - 142
# 142 - * - 143
# 143 - lh4.googleusercontent.com - 143
# 143 - * - 144
# 144 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 1 - 107
# 107 - * - 108
# 108 - * - 109
# 109 - google.com - 145
# 145 - * - 146
# 146 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 443 - 142
# 142 - * - 143
# 143 - clients4.google.com - 147
# 147 - * - 148
# 148 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - * - 127
# 127 - 8008 - 149
# 149 - * - 150
# 150 - * - 151
# 151 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 123 - 78
# 78 - * - 79
# ...
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - 15373.live.streamtheworld.com - 110
# 110 - * - 111
# 111 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 5228 - 154
# 154 - * - 155
# 155 - sip.aws.invoxia.io - 155
# 155 - * - 155
# 155 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 10002 - 156
# 156 - * - 157
# 157 - sip.aws.invoxia.io - 158
# 158 - * - 159
# 159 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - developer.invoxia.com - 160
# 160 - * - 161
# 161 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - whatismyip.akamai.com - 162
# 162 - * - 163
# 163 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 67 - 103
# 103 - * - 104
# 104 - * - 105
# 105 - * - 106
# 106 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - ws.invoxia.io - 107
# 107 - * - 108
# 108 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - esdk-ffl.spotify.com - 109
# 109 - * - 110
# 110 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 123 - 78
# 78 - * - 79
# 79 - 0.invoxia.pool.ntp.org - 111
# 111 - * - 112
# 112 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 123 - 78
# 78 - * - 79
# 79 - 3.invoxia.pool.ntp.org - 113
# 113 - * - 114
# 114 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 8090 - 115
# 115 - * - 116
# 116 - crossbar.invoxia.io - 117
# 117 - * - 118
# 118 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 58 - 122
# 122 - * - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 17 - 118
# 118 - * - 119
# 119 - 5353 - 130
# 130 - * - 130
# 130 - * - 131
# 131 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 58 - 122
# 122 - * - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 0 - 130
# 130 - * - 131
# 131 - * - 132
# 132 - * - 133
# 133 - * - 134
# 134 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0006 - 117
# 117 - * - 118
# 118 - * - 119
# 119 - * - 120
# 120 - * - 121
# 121 - * - 122
# 122 - forward
# * - 33
# 33 - * - 34
# 34 - 0x888e - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 15
# 15 - 2 - 16
# 16 - * - 17
# 17 - * - 18
# 18 - * - 19
# 19 - 224.0.0.22/32 - 20
# 20 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 8443 - 124
# 124 - * - 125
# 125 - xbcs.net - 125
# 125 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 1900 - 21
# 21 - * - 22
# 22 - 239.255.255.250/32 - 23
# 23 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 24
# 24 - 0x0800 - 25
# 25 - 17 - 26
# 26 - * - 27
# 27 - 67 - 28
# 28 - * - 29
# 29 - 255.255.255.255/32 - 30
# 30 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 123 - 12
# 12 - * - 13
# 13 - 129.132.2.21/32 - 31
# 31 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 1 - 36
# 36 - * - 37
# 37 - * - 38
# 38 - * - 39
# 39 - * - 40
# 40 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 3478 - 41
# 41 - * - 42
# 42 - tunnel.xbcs.net - 42
# 42 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 8899 - 58
# 58 - * - 59
# 59 - devices.xbcs.net - 60
# 60 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 15
# 15 - 2 - 16
# 16 - * - 17
# 17 - * - 18
# 18 - * - 19
# 19 - 239.255.255.250/32 - 130
# 130 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 53 - 46
# 46 - * - 47
# 47 - * - 48
# 48 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - 49152 - 126
# 126 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - * - 129
# 129 - * - 130
# 130 - * - 131
# 131 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 15
# 15 - 2 - 16
# 16 - * - 17
# 17 - * - 18
# 18 - * - 19
# 19 - 224.0.0.2/32 - 133
# 133 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 123 - 12
# 12 - * - 13
# 13 - 132.163.4.102/32 - 134
# 134 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - 49153 - 126
# 126 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 123 - 78
# 78 - * - 79
# 79 - 129.132.2.21/32 - 129
# 129 - * - 129
# 129 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 1 - 36
# 36 - * - 37
# 37 - * - 38
# 38 - * - 39
# 39 - * - 40
# 40 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - * - 129
# 129 - * - 130
# 130 - * - 131
# 131 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 53 - 88
# 88 - * - 89
# 89 - * - 90
# 90 - * - 91
# 91 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - * - 127
# 127 - 49153 - 127
# 127 - * - 128
# 128 - * - 129
# 129 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 8443 - 130
# 130 - * - 131
# 131 - xbcs.net - 131
# 131 - * - 132
# 132 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 67 - 103
# 103 - * - 104
# 104 - * - 105
# 105 - * - 106
# 106 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 8899 - 130
# 130 - * - 131
# 131 - devices.xbcs.net - 131
# 131 - * - 132
# 132 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - * - 127
# 127 - 49152 - 132
# 132 - * - 133
# 133 - * - 134
# 134 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 123 - 78
# 78 - * - 79
# 79 - 132.163.4.102/32 - 135
# 135 - * - 135
# 135 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 3478 - 136
# 136 - * - 137
# 137 - tunnel.xbcs.net - 138
# 138 - * - 139
# 139 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 0 - 130
# 130 - * - 131
# 131 - * - 132
# 132 - * - 133
# 133 - * - 134
# 134 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 58 - 122
# 122 - * - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - forward
# * - 33
# 33 - * - 34
# 34 - * - 117
# 117 - 58 - 122
# 122 - * - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - forward
# * - 33
# 33 - * - 34
# 34 - 0x888e - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0006 - 117
# 117 - * - 118
# 118 - * - 119
# 119 - * - 120
# 120 - * - 121
# 121 - * - 122
# 122 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 8443 - 124
# 124 - * - 125
# 125 - api.xbcs.net - 125
# 125 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 67 - 59
# 59 - * - 60
# 60 - * - 61
# 61 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 15
# 15 - 2 - 16
# 16 - * - 17
# 17 - * - 18
# 18 - * - 19
# 19 - 224.0.0.22/32 - 20
# 20 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 1900 - 21
# 21 - * - 22
# 22 - 239.255.255.250/32 - 23
# 23 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 24
# 24 - 0x0800 - 25
# 25 - 17 - 26
# 26 - * - 27
# 27 - 67 - 28
# 28 - * - 29
# 29 - 255.255.255.255/32 - 30
# 30 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - * - 127
# 127 - 3478 - 127
# 127 - * - 128
# 128 - * - 129
# 129 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - 208.67.222.222/32 - 130
# 130 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 123 - 12
# 12 - * - 13
# 13 - 129.132.2.21/32 - 31
# 31 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 1 - 36
# 36 - * - 37
# 37 - * - 38
# 38 - * - 39
# 39 - * - 40
# 40 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - 4.2.2.2/32 - 54
# 54 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 53 - 46
# 46 - * - 47
# 47 - * - 48
# 48 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - 49154 - 126
# 126 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 123 - 12
# 12 - * - 13
# 13 - 130.149.17.8/32 - 129
# 129 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - * - 129
# 129 - * - 130
# 130 - * - 131
# 131 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 3475 - 55
# 55 - * - 56
# 56 - nat.xbcs.net - 132
# 132 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 1 - 51
# 51 - * - 52
# 52 - * - 53
# 53 - * - 54
# 54 - 8.8.8.8/32 - 74
# 74 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - 49153 - 126
# 126 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 1 - 36
# 36 - * - 37
# 37 - * - 38
# 38 - * - 39
# 39 - * - 40
# 40 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 53 - 88
# 88 - * - 89
# 89 - * - 90
# 90 - * - 91
# 91 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - * - 127
# 127 - 49153 - 127
# 127 - * - 128
# 128 - * - 129
# 129 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 123 - 78
# 78 - * - 79
# 79 - 130.149.17.8/32 - 130
# 130 - * - 131
# 131 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 17 - 77
# 77 - 123 - 78
# 78 - * - 79
# 79 - 129.132.2.21/32 - 129
# 129 - * - 129
# 129 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 1 - 107
# 107 - * - 108
# 108 - * - 109
# 109 - 4.2.2.2/32 - 130
# 130 - * - 131
# 131 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - * - 127
# 127 - 49154 - 138
# 138 - * - 139
# 139 - * - 140
# 140 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - * - 129
# 129 - * - 130
# 130 - * - 131
# 131 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 67 - 103
# 103 - * - 104
# 104 - * - 105
# 105 - * - 106
# 106 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 1 - 107
# 107 - * - 108
# 108 - * - 109
# 109 - 8.8.8.8/32 - 109
# 109 - * - 110
# 110 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 1 - 107
# 107 - * - 108
# 108 - * - 109
# 109 - 208.67.222.222/32 - 111
# 111 - * - 112
# 112 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 6 - 126
# 126 - 3478 - 126
# 126 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 3475 - 113
# 113 - * - 114
# 114 - nat.xbcs.net - 129
# 129 - * - 129
# 129 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 8443 - 130
# 130 - * - 131
# 131 - api.xbcs.net - 131
# 131 - * - 132
# 132 - forward
# * - 33
# 33 - * - 34
# 34 - 0x888e - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0006 - 117
# 117 - * - 118
# 118 - * - 119
# 119 - * - 120
# 120 - * - 121
# 121 - * - 122
# 122 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 1935 - 123
# 123 - * - 124
# 124 - fr-eqx-fwd-06.withings.com - 124
# 124 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 1935 - 123
# 123 - * - 124
# 124 - fr-on-fwd-03.withings.net - 125
# 125 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 53 - 46
# 46 - * - 47
# 47 - * - 48
# 48 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 24
# 24 - 0x0800 - 25
# 25 - 17 - 26
# 26 - * - 27
# 27 - 67 - 28
# 28 - * - 29
# 29 - 255.255.255.255/32 - 30
# 30 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 1935 - 123
# 123 - * - 124
# 124 - fr-on-vm-02-lxc-03.withings.net - 124
# 124 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 1935 - 123
# 123 - * - 124
# 124 - fr-on-vm-02-lxc-05.withings.net - 125
# 125 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 1935 - 123
# 123 - * - 124
# 124 - us-iweb-fwd-01-lxc-04.withings.net - 126
# 126 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 5353 - 66
# 66 - * - 67
# 67 - 224.0.0.251/32 - 68
# 68 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 1935 - 123
# 123 - * - 124
# 124 - fr-ovh-fwd-03.withings.net - 124
# 124 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - babyws.withings.net - 125
# 125 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - babyws.withings.net - 126
# 126 - * - 126
# 126 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 1935 - 127
# 127 - * - 128
# 128 - fr-on-vm-02-lxc-03.withings.net - 128
# 128 - * - 129
# 129 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 53 - 88
# 88 - * - 89
# 89 - * - 90
# 90 - * - 91
# 91 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 67 - 103
# 103 - * - 104
# 104 - * - 105
# 105 - * - 106
# 106 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 1935 - 127
# 127 - * - 128
# 128 - fr-ovh-fwd-03.withings.net - 128
# 128 - * - 129
# 129 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 1935 - 127
# 127 - * - 128
# 128 - fr-on-fwd-03.withings.net - 130
# 130 - * - 131
# 131 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 1935 - 127
# 127 - * - 128
# 128 - fr-on-vm-02-lxc-05.withings.net - 132
# 132 - * - 133
# 133 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 1935 - 127
# 127 - * - 128
# 128 - fr-eqx-fwd-06.withings.com - 134
# 134 - * - 135
# 135 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 1935 - 127
# 127 - * - 128
# 128 - us-iweb-fwd-01-lxc-04.withings.net - 136
# 136 - * - 137
# 137 - forward
# * - 33
# 33 - ff:ff:ff:ff:ff:ff - 43
# 43 - 0x0800 - 44
# 44 - 17 - 44
# 44 - * - 45
# 45 - 67 - 59
# 59 - * - 60
# 60 - * - 61
# 61 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - wbs04-ws.withings.net - 62
# 62 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 53 - 46
# 46 - * - 47
# 47 - * - 48
# 48 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 24
# 24 - 0x0800 - 25
# 25 - 17 - 26
# 26 - * - 27
# 27 - 67 - 28
# 28 - * - 29
# 29 - 255.255.255.255/32 - 30
# 30 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - wbs04-ws.withings.net - 86
# 86 - * - 87
# 87 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 53 - 88
# 88 - * - 89
# 89 - * - 90
# 90 - * - 91
# 91 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 67 - 103
# 103 - * - 104
# 104 - * - 105
# 105 - * - 106
# 106 - forward
# * - 33
# 33 - * - 34
# 34 - 0x888e - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0006 - 117
# 117 - * - 118
# 118 - * - 119
# 119 - * - 120
# 120 - * - 121
# 121 - * - 122
# 122 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 443 - 6
# 6 - * - 7
# 7 - scalews.withings.net - 123
# 123 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - * - 45
# 45 - 53 - 46
# 46 - * - 47
# 47 - * - 48
# 48 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 15
# 15 - 2 - 16
# 16 - * - 17
# 17 - * - 18
# 18 - * - 19
# 19 - 224.0.0.22/32 - 20
# 20 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 24
# 24 - 0x0800 - 25
# 25 - 17 - 26
# 26 - * - 27
# 27 - 67 - 28
# 28 - * - 29
# 29 - 255.255.255.255/32 - 30
# 30 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 6 - 4
# 4 - * - 5
# 5 - 80 - 41
# 41 - * - 42
# 42 - scalews.withings.net - 42
# 42 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0800 - 3
# 3 - 17 - 10
# 10 - * - 11
# 11 - 5353 - 66
# 66 - * - 67
# 67 - 224.0.0.251/32 - 68
# 68 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 53 - 88
# 88 - * - 89
# 89 - * - 90
# 90 - * - 91
# 91 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 443 - 85
# 85 - * - 86
# 86 - scalews.withings.net - 92
# 92 - * - 93
# 93 - forward
# * - 33
# 33 - * - 34
# 34 - 0x0800 - 35
# 35 - 17 - 44
# 44 - 67 - 103
# 103 - * - 104
# 104 - * - 105
# 105 - * - 106
# 106 - forward
# * - 33
# 33 - 9e:8d:de:80:29:28 - 75
# 75 - 0x0800 - 76
# 76 - 6 - 84
# 84 - 80 - 99
# 99 - * - 100
# 100 - scalews.withings.net - 107
# 107 - * - 108
# 108 - forward
# * - 33
# 33 - * - 34
# 34 - 0x888e - 123
# 123 - * - 124
# 124 - * - 125
# 125 - * - 126
# 126 - * - 127
# 127 - * - 128
# 128 - forward

# %%
workbook1.close()

# %%
counter=1
counter1=0
count=[]
count1=[]
count2=[]
count3=[]
count4=[]
count5=[]
count6=[]
count7=[]
previous_count=[]
previous_count1=[]
previous_count2=[]
previous_count3=[]
previous_count4=[]
previous_count5=[]
previous_count6=[]
for i in range(len(data)) :
    length=len(data[i])
    for j in range(len(data[i])) :
        if j==0:
            flag=0
            if i==0:
                print(data[i][j],'-',counter)
                #print(data[i][j],'-',temp)
                workbook1.sheetnames[columns[j]].write("A1","sEth")
                workbook1.sheetnames[columns[j]].write("B1","state")
                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                count.append(counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print("for loop")
                    if data[k][j]==data[i][j]:
                        #print("IF loop")
                        flag=1
                        #var=k
                        previous_counter=count[k]
                        print(data[i][j],'-',previous_counter)
                        break
                        
                if flag==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(data[i][j],'-',counter)
                    #print(data[i][j],'-',temp)
                    workbook1.sheetnames[columns[j]].write("A1","sEth")
                    workbook1.sheetnames[columns[j]].write("B1","state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                    count.append(counter)
                    #previous_counter=counter
                    previous_counter=counter
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=counter+1
                    #temp=counter
        elif j==length-1:
            print(previous_counter,'-',data[i][j])
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1","Action")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            #n=n+1
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            temp=previous_counter+1
        elif j==1:
            flag1=0
            f1=0
            #f=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count1.append(counter)
                previous_count.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count[k]==previous_counter:
                        flag1=1
                        counter=count1[k]
                        count1.append(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count.append(previous_counter)
                        f1=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count[k]!=previous_counter:
                        flag1=1
                        f1=2
                            
                if f1==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count.append(previous_counter)
                    count1.append(counter)
                    previous_counter=counter
                        #previous_count[i][j]=previous_counter
                    counter=counter+1
                if flag1==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count1.append(counter)
                    #print(count1)
                    previous_count.append(previous_counter)
                    #print(previous_count)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
        elif j==2:
            flag2=0
            f=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count2.append(counter)
                previous_count1.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print(k)
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count1[k]==previous_counter:
                        #print("IF loop")
                        flag2=1
                        f=1
                        #if previous_count1[k]==previous_counter:
                        counter=count2[k]
                        count2.append(counter)
                        #print(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count1.append(previous_counter)
                            #f=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count1[k]!=previous_counter:
                        flag2=1
                        f=2
                if f==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count1.append(previous_counter)
                    count2.append(counter)
                    previous_counter=counter
                            #previous_count[i][j]=previous_counter
                    counter=counter+1
                    
                if flag2==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count2.append(counter)
                    #print(count2)
                    previous_count1.append(previous_counter)
                   # print(previous_count1)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
# Out:
# 9e:8d:de:80:29:28 - 1
# 1 ff:ff:ff:ff:ff:ff - 2
# 2 0x0800 - 3
# 3 - forward
# * - 4
# 4 - 9e:8d:de:80:29:28 - 5
# 5 - 0x0800 - 6
# 6 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0006 - 4
# 4 - forward
# * - 4
# 4 - 9e:8d:de:80:29:28 - 5
# 5 - 0x0800 - 6
# 6 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - forward
# * - 4
# 4 - 9e:8d:de:80:29:28 - 5
# 5 - 0x0800 - 6
# 6 - forward
# * - 4
# 4 - 9e:8d:de:80:29:28 - 5
# 5 - 0x0800 - 6
# 6 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 2
# 2 - 0x0800 - 3
# 3 - forward
# * - 4
# 4 - 9e:8d:de:80:29:28 - 5
# 5 - * - 5
# 5 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 6
# 6 - * - 7
# 7 - forward
# * - 4
# 4 - 9e:8d:de:80:29:28 - 5
# 5 - * - 5
# 5 - forward
# * - 4
# 4 - * - 6
# 6 - * - 7
# 7 - deny

# %%
counter=1
counter1=0
count=[]
count1=[]
count2=[]
count3=[]
count4=[]
count5=[]
count6=[]
count7=[]
previous_count=[]
previous_count1=[]
previous_count2=[]
previous_count3=[]
previous_count4=[]
previous_count5=[]
previous_count6=[]
for i in range(len(data)) :
    length=len(data[i])
    for j in range(len(data[i])) :
        if j==0:
            flag=0
            if i==0:
                print(data[i][j],'-',counter)
                #print(data[i][j],'-',temp)
                workbook1.sheetnames[columns[j]].write("A1","sEth")
                workbook1.sheetnames[columns[j]].write("B1","state")
                workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                count.append(counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print("for loop")
                    if data[k][j]==data[i][j]:
                        #print("IF loop")
                        flag=1
                        #var=k
                        previous_counter=count[k]
                        count.append(counter)
                        print(data[i][j],'-',previous_counter)
                        break
                        
                if flag==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(data[i][j],'-',counter)
                    #print(data[i][j],'-',temp)
                    workbook1.sheetnames[columns[j]].write("A1","sEth")
                    workbook1.sheetnames[columns[j]].write("B1","state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,1,counter)
                    count.append(counter)
                    #previous_counter=counter
                    previous_counter=counter
                    #previous_count[i][j]=previous_counter
                    #counter=counter+1
                    counter=counter+1
                    #temp=counter
        elif j==length-1:
            print(previous_counter,'-',data[i][j])
            workbook1.sheetnames[columns[j]].write("A1","Previous_state")
            workbook1.sheetnames[columns[j]].write("B1","Action")
            workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
            #n=n+1
            workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
            temp=previous_counter+1
        elif j==1:
            flag1=0
            f1=0
            #f=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count1.append(counter)
                previous_count.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count[k]==previous_counter:
                        flag1=1
                        counter=count1[k]
                        count1.append(counter)  
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count.append(previous_counter)
                        f1=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count[k]!=previous_counter:
                        flag1=1
                        f1=2
                            
                if f1==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count.append(previous_counter)
                    count1.append(counter)
                    previous_counter=counter
                        #previous_count[i][j]=previous_counter
                    counter=counter+1
                if flag1==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count1.append(counter)
                    #print(count1)
                    previous_count.append(previous_counter)
                    #print(previous_count)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
        elif j==2:
            flag2=0
            f=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count2.append(counter)
                previous_count1.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print(k)
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count1[k]==previous_counter:
                        #print("IF loop")
                        flag2=1
                        f=1
                        #if previous_count1[k]==previous_counter:
                        counter=count2[k]
                        count2.append(counter)
                        #print(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count1.append(previous_counter)
                            #f=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count1[k]!=previous_counter:
                        flag2=1
                        f=2
                if f==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count1.append(previous_counter)
                    count2.append(counter)
                    previous_counter=counter
                            #previous_count[i][j]=previous_counter
                    counter=counter+1
                    
                if flag2==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count2.append(counter)
                    #print(count2)
                    previous_count1.append(previous_counter)
                   # print(previous_count1)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
        elif j==3:
            flag3=0
            f2=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count3.append(counter)
                previous_count2.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print(k)
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count2[k]==previous_counter:
                        #print("IF loop")
                        flag3=1
                        f2=1
                        #if previous_count1[k]==previous_counter:
                        counter=count3[k]
                        count3.append(counter)
                        #print(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count2.append(previous_counter)
                            #f=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count2[k]!=previous_counter:
                        flag3=1
                        f2=2
                if f2==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count2.append(previous_counter)
                    count3.append(counter)
                    previous_counter=counter
                            #previous_count[i][j]=previous_counter
                    counter=counter+1
                    
                if flag3==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count3.append(counter)
                    #print(count2)
                    previous_count2.append(previous_counter)
                   # print(previous_count1)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
        elif j==4:
            flag4=0
            f3=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count4.append(counter)
                previous_count3.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print(k)
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count3[k]==previous_counter:
                        #print("IF loop")
                        flag4=1
                        f3=1
                        #if previous_count1[k]==previous_counter:
                        counter=count4[k]
                        count4.append(counter)
                        #print(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count3.append(previous_counter)
                            #f=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count3[k]!=previous_counter:
                        flag4=1
                        f3=2
                if f3==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count3.append(previous_counter)
                    count4.append(counter)
                    previous_counter=counter
                            #previous_count[i][j]=previous_counter
                    counter=counter+1
                    
                if flag4==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count4.append(counter)
                    #print(count2)
                    previous_count3.append(previous_counter)
                   # print(previous_count1)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
        elif j==5:
            flag5=0
            f4=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count5.append(counter)
                previous_count4.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print(k)
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count4[k]==previous_counter:
                        #print("IF loop")
                        flag5=1
                        f4=1
                        #if previous_count1[k]==previous_counter:
                        counter=count5[k]
                        count5.append(counter)
                        #print(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count4.append(previous_counter)
                            #f=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count4[k]!=previous_counter:
                        flag5=1
                        f4=2
                if f4==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count4.append(previous_counter)
                    count5.append(counter)
                    previous_counter=counter
                            #previous_count[i][j]=previous_counter
                    counter=counter+1
                    
                if flag5==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count5.append(counter)
                    #print(count2)
                    previous_count4.append(previous_counter)
                   # print(previous_count1)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
        elif j==6:
            flag6=0
            f5=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count6.append(counter)
                previous_count5.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print(k)
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count5[k]==previous_counter:
                        #print("IF loop")
                        flag6=1
                        f5=1
                        #if previous_count1[k]==previous_counter:
                        counter=count6[k]
                        count6.append(counter)
                        #print(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count5.append(previous_counter)
                            #f=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count5[k]!=previous_counter:
                        flag6=1
                        f5=2
                if f5==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count5.append(previous_counter)
                    count6.append(counter)
                    previous_counter=counter
                            #previous_count[i][j]=previous_counter
                    counter=counter+1
                    
                if flag6==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count6.append(counter)
                    #print(count2)
                    previous_count5.append(previous_counter)
                   # print(previous_count1)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
        elif j==7:
            flag7=0
            f6=0
            if i==0:
                print(previous_counter, data[i][j],'-',counter)
                workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                workbook1.sheetnames[columns[j]].write("C1","next_state")
                workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                count7.append(counter)
                previous_count6.append(previous_counter)
                previous_counter=counter
                #previous_count[i][j]=previous_counter
                counter=counter+1
                #temp=counter
            else:
                for k in range(0,i):
                    #print(k)
                    #print("for loop")
                    if data[k][j]==data[i][j] and previous_count6[k]==previous_counter:
                        #print("IF loop")
                        flag7=1
                        f6=1
                        #if previous_count1[k]==previous_counter:
                        counter=count7[k]
                        count7.append(counter)
                        #print(counter)
                            
                        print(previous_counter,'-',data[i][j],'-',counter)
                        previous_counter=counter
                        previous_count6.append(previous_counter)
                            #f=1
                        break
                        
                    elif data[k][j]==data[i][j] and previous_count6[k]!=previous_counter:
                        flag7=1
                        f6=2
                if f6==2:
                    counter=max(counter,temp)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    previous_count6.append(previous_counter)
                    count7.append(counter)
                    previous_counter=counter
                            #previous_count[i][j]=previous_counter
                    counter=counter+1
                    
                if flag7==0:
                    #print("outer loop")
                    counter=max(temp,counter)
                    print(previous_counter,'-',data[i][j],'-',counter)
                    workbook1.sheetnames[columns[j]].write("A1","Previous_state")
                    workbook1.sheetnames[columns[j]].write("B1", columns[j]) 
                    workbook1.sheetnames[columns[j]].write("C1","next_state")
                    workbook1.sheetnames[columns[j]].write(i+1,0,previous_counter)
                    workbook1.sheetnames[columns[j]].write(i+1,1,data[i][j])
                    workbook1.sheetnames[columns[j]].write(i+1,2,counter)
                    count7.append(counter)
                    #print(count2)
                    previous_count6.append(previous_counter)
                   # print(previous_count1)
                    #previous_counter=counter
                    previous_counter=counter
                    counter=counter+1
                    #temp=counter
# Out:
# 9e:8d:de:80:29:28 - 1
# 1 * - 2
# 2 * - 3
# 3 * - 4
# 4 dcape-na.amazon.com - 5
# 5 6 - 6
# 6 * - 7
# 7 443 - 8
# 8 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - softwareupdates.amazon.com - 9
# 9 - 6 - 10
# 10 - * - 11
# 11 - 443 - 12
# 12 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 3.north-america.pool.ntp.org - 13
# 13 - 17 - 14
# 14 - * - 15
# 15 - 123 - 16
# 16 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 224.0.0.22/32 - 17
# 17 - 2 - 18
# 18 - * - 19
# 19 - * - 20
# 20 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 239.255.255.250/32 - 21
# 21 - 17 - 22
# 22 - * - 23
# 23 - 1900 - 24
# 24 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - ff:ff:ff:ff:ff:ff - 25
# 25 - 0x0800 - 26
# 26 - * - 27
# 27 - 255.255.255.255/32 - 28
# 28 - 17 - 29
# 29 - * - 30
# 30 - 67 - 31
# 31 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ntp-g7g.amazon.com - 32
# 32 - 17 - 33
# 33 - * - 34
# 34 - 123 - 35
# 35 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - todo-ta-g7g.amazon.com - 36
# 36 - 6 - 37
# 37 - * - 38
# 38 - 443 - 39
# 39 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 1 - 41
# 41 - * - 42
# 42 - * - 43
# 43 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.example.org - 44
# 44 - 6 - 45
# 45 - * - 46
# 46 - 80 - 47
# 47 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 17 - 48
# 48 - * - 49
# 49 - 53 - 50
# 50 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - pindorama-us-west-2.amazon.com - 51
# 51 - 6 - 52
# 52 - * - 53
# 53 - 443 - 54
# 54 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - tinytts-us-west-2.amazon.com - 55
# 55 - 6 - 56
# 56 - * - 57
# 57 - 443 - 58
# 58 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 208.67.220.220/32 - 59
# 59 - 17 - 60
# 60 - * - 61
# 61 - 53 - 62
# 62 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - device-fingerprintdb-v1.s3.amazonaws.com - 63
# 63 - 6 - 64
# 64 - * - 65
# 65 - 443 - 66
# 66 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - api.amazonalexa.com - 67
# 67 - 6 - 68
# 68 - * - 69
# 69 - 443 - 70
# 70 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.example.com - 71
# 71 - 6 - 72
# 72 - * - 73
# 73 - 80 - 74
# 74 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 1.north-america.pool.ntp.org - 75
# 75 - 17 - 76
# 76 - * - 77
# 77 - 123 - 78
# 78 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.meethue.com - 79
# 79 - 6 - 80
# 80 - * - 81
# 81 - 443 - 82
# 82 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 17 - 48
# 48 - * - 49
# 49 - 67 - 83
# 83 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 2.north-america.pool.ntp.org - 84
# 84 - 17 - 85
# 85 - * - 86
# 86 - 123 - 87
# 87 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - kindle-time.amazon.com - 88
# 88 - 6 - 89
# 89 - * - 90
# 90 - 80 - 91
# 91 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - device-metrics-us.amazon.com - 92
# 92 - 6 - 93
# 93 - * - 94
# 94 - 443 - 95
# 95 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - files.whooshkaa.com - 96
# 96 - 6 - 97
# 97 - * - 98
# 98 - 443 - 99
# 99 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 224.0.0.251/32 - 100
# 100 - 17 - 101
# 101 - * - 102
# 102 - 5353 - 103
# 103 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - pins.amazon.com - 104
# 104 - 17 - 105
# 105 - * - 106
# 106 - 33434 - 107
# 107 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - media.whooshkaa.com - 108
# 108 - 6 - 109
# 109 - * - 110
# 110 - 443 - 111
# 111 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 0.north-america.pool.ntp.org - 112
# 112 - 17 - 113
# 113 - * - 114
# 114 - 123 - 115
# 115 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.example.net - 116
# 116 - 6 - 117
# 117 - * - 118
# 118 - 80 - 119
# 119 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - north-america.pool.ntp.org - 123
# 123 - * - 124
# 124 - 17 - 125
# 125 - 123 - 126
# 126 - * - 127
# 127 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ntp-g7g.amazon.com - 128
# 128 - * - 129
# 129 - 17 - 130
# 130 - 123 - 131
# 131 - * - 132
# 132 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - api.amazonalexa.com - 133
# 133 - * - 134
# 134 - 6 - 135
# 135 - 443 - 136
# 136 - * - 137
# 137 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - tinytts-us-west-2.amazon.com - 138
# 138 - * - 139
# 139 - 6 - 140
# 140 - 443 - 141
# 141 - * - 142
# 142 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - north-america.pool.ntp.org - 123
# 123 - * - 124
# 124 - 17 - 125
# 125 - 123 - 126
# 126 - * - 127
# 127 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - todo-ta-g7g.amazon.com - 128
# 128 - * - 129
# 129 - 6 - 129
# 129 - 443 - 130
# 130 - * - 131
# 131 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - north-america.pool.ntp.org - 123
# 123 - * - 124
# 124 - 17 - 125
# 125 - 123 - 126
# 126 - * - 127
# 127 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - north-america.pool.ntp.org - 123
# 123 - * - 124
# 124 - 17 - 125
# 125 - 123 - 126
# 126 - * - 127
# 127 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - www.example.com - 128
# 128 - * - 129
# 129 - 6 - 129
# 129 - 80 - 129
# 129 - * - 130
# 130 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 17 - 48
# 48 - 67 - 131
# 131 - * - 132
# 132 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 208.67.220.220/32 - 133
# 133 - * - 134
# 134 - 17 - 134
# 134 - 53 - 135
# 135 - * - 136
# 136 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - device-metrics-us.amazon.com - 137
# 137 - * - 138
# 138 - 6 - 139
# 139 - 443 - 140
# 140 - * - 141
# 141 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - device-fingerprintdb-v1.s3.amazonaws.com - 142
# 142 - * - 143
# 143 - 6 - 144
# 144 - 443 - 145
# 145 - * - 146
# 146 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 17 - 48
# 48 - 53 - 147
# 147 - * - 148
# 148 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - dcape-na.amazon.com - 149
# 149 - * - 150
# 150 - 6 - 151
# 151 - 443 - 152
# 152 - * - 153
# 153 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - www.meethue.com - 154
# 154 - * - 155
# 155 - 6 - 156
# 156 - 443 - 157
# 157 - * - 158
# 158 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - files.whooshkaa.com - 159
# 159 - * - 160
# 160 - 6 - 161
# 161 - 443 - 162
# 162 - * - 163
# 163 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - pins.amazon.com - 164
# 164 - * - 165
# 165 - 17 - 166
# 166 - 33434 - 167
# 167 - * - 168
# 168 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - kindle-time.amazon.com - 169
# 169 - * - 170
# 170 - 6 - 171
# 171 - 80 - 172
# 172 - * - 173
# 173 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - media.whooshkaa.com - 174
# 174 - * - 175
# 175 - 6 - 176
# 176 - 443 - 177
# 177 - * - 178
# 178 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - softwareupdates.amazon.com - 179
# 179 - * - 180
# 180 - 6 - 181
# 181 - 443 - 182
# 182 - * - 183
# 183 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - www.example.net - 184
# 184 - * - 185
# 185 - 6 - 186
# 186 - 80 - 187
# 187 - * - 188
# 188 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 17 - 48
# 48 - * - 49
# 49 - 50000 - 189
# 189 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - www.example.org - 190
# 190 - * - 191
# 191 - 6 - 192
# 192 - 80 - 193
# 193 - * - 194
# 194 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - pindorama-us-west-amazon.com - 195
# 195 - * - 196
# 196 - 6 - 197
# 197 - 443 - 198
# 198 - * - 199
# 199 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x0006 - 200
# 200 - * - 201
# 201 - * - 202
# 202 - * - 203
# 203 - * - 204
# 204 - * - 205
# 205 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - 0x888e - 206
# 206 - * - 207
# 207 - * - 208
# 208 - * - 209
# 209 - * - 210
# 210 - * - 211
# 211 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 336971aac5bba454b967-3ec27f5c732731b07836c69a45967ad6.ssl.cf1.rackcdn.com - 212
# 212 - 6 - 213
# 213 - * - 214
# 214 - 443 - 215
# 215 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - rpsv2.video-cloud.net - 216
# 216 - 6 - 217
# 217 - * - 218
# 218 - 443 - 219
# 219 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - iconfig.august.com - 220
# 220 - 6 - 221
# 221 - * - 222
# 222 - 443 - 223
# 223 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - rpsv12.video-cloud.net - 224
# 224 - 6 - 225
# 225 - * - 226
# 226 - 443 - 227
# 227 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - vcsv2.video-cloud.net - 228
# 228 - 6 - 229
# 229 - * - 230
# 230 - 443 - 231
# 231 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 8.8.4.4/32 - 232
# 232 - 1 - 233
# 233 - * - 234
# 234 - * - 235
# 235 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - rpsv3.video-cloud.net - 236
# 236 - 6 - 237
# 237 - * - 238
# 238 - 443 - 239
# 239 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - doorbells.august.com - 240
# 240 - 1 - 241
# 241 - * - 242
# 242 - * - 243
# 243 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - rpsv7.video-cloud.net - 244
# 244 - 6 - 245
# 245 - * - 246
# 246 - 443 - 247
# 247 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - v2servers.video-cloud.net - 248
# 248 - 6 - 249
# 249 - * - 250
# 250 - 443 - 251
# 251 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 8.8.8.8/32 - 252
# 252 - 17 - 253
# 253 - * - 254
# 254 - 53 - 255
# 255 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - rpsv11.video-cloud.net - 256
# 256 - 6 - 257
# 257 - * - 258
# 258 - 443 - 259
# 259 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - rpsv222.video-cloud.net - 260
# 260 - 6 - 261
# 261 - * - 262
# 262 - 443 - 263
# 263 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - august.pubnub.com - 264
# 264 - 6 - 265
# 265 - * - 266
# 266 - 443 - 267
# 267 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - logger.august.com - 268
# 268 - 6 - 269
# 269 - * - 270
# 270 - 443 - 271
# 271 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - s3-us-west-2.amazonaws.com - 272
# 272 - 6 - 273
# 273 - * - 274
# 274 - 443 - 275
# 275 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - rpsv4.video-cloud.net - 276
# 276 - 6 - 277
# 277 - * - 278
# 278 - 443 - 279
# 279 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - doorbells.august.com - 240
# 240 - 6 - 280
# 280 - * - 281
# 281 - 443 - 282
# 282 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - rbs-sticky.august.com - 283
# 283 - 6 - 284
# 284 - * - 285
# 285 - 443 - 286
# 286 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - rpsv1.video-cloud.net - 287
# 287 - 6 - 288
# 288 - * - 289
# 289 - 443 - 290
# 290 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - rpsv10.video-cloud.net - 291
# 291 - 6 - 292
# 292 - * - 293
# 293 - 443 - 294
# 294 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - rpsv5.video-cloud.net - 295
# 295 - 6 - 296
# 296 - * - 297
# 297 - 443 - 298
# 298 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - dmsv2.video-cloud.net - 299
# 299 - 6 - 300
# 300 - * - 301
# 301 - 443 - 302
# 302 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 8.8.8.8/32 - 252
# 252 - 1 - 303
# 303 - * - 304
# 304 - * - 305
# 305 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - rpsv7.video-cloud.net - 306
# 306 - * - 307
# 307 - 6 - 308
# 308 - 443 - 309
# 309 - * - 310
# 310 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - august.pubnub.com - 311
# 311 - * - 312
# 312 - 6 - 313
# 313 - 443 - 314
# 314 - * - 315
# 315 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - rpsv2.video-cloud.net - 316
# 316 - * - 317
# 317 - 6 - 318
# 318 - 443 - 319
# 319 - * - 320
# 320 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - s3-us-west-2.amazonaws.com - 321
# 321 - * - 322
# 322 - 6 - 323
# 323 - 443 - 324
# 324 - * - 325
# 325 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - logger.august.com - 326
# 326 - * - 327
# 327 - 6 - 328
# 328 - 443 - 329
# 329 - * - 330
# 330 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 336971aac5bba454b967-3ec27f5c732731b07836c69a45967ad6.ssl.cf1.rackcdn.com - 331
# 331 - * - 332
# 332 - 6 - 333
# 333 - 443 - 334
# 334 - * - 335
# 335 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - rpsv11.video-cloud.net - 336
# 336 - * - 337
# 337 - 6 - 338
# 338 - 443 - 339
# 339 - * - 340
# 340 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - dmsv2.video-cloud.net - 341
# 341 - * - 342
# 342 - 6 - 343
# 343 - 443 - 344
# 344 - * - 345
# 345 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - doorbells.august.com - 346
# 346 - * - 347
# 347 - 1 - 348
# 348 - * - 349
# 349 - * - 350
# 350 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 8.8.8.8/32 - 351
# 351 - * - 352
# 352 - 17 - 353
# 353 - 53 - 354
# 354 - * - 355
# 355 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - rpsv1.video-cloud.net - 356
# 356 - * - 357
# 357 - 6 - 358
# 358 - 443 - 359
# 359 - * - 360
# 360 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - rpsv4.video-cloud.net - 361
# 361 - * - 362
# 362 - 6 - 363
# 363 - 443 - 364
# 364 - * - 365
# 365 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - rpsv3.video-cloud.net - 366
# 366 - * - 367
# 367 - 6 - 368
# 368 - 443 - 369
# 369 - * - 370
# 370 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - v2servers.video-cloud.net - 371
# 371 - * - 372
# 372 - 6 - 373
# 373 - 443 - 374
# 374 - * - 375
# 375 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - iconfig.august.com - 376
# 376 - * - 377
# 377 - 6 - 378
# 378 - 443 - 379
# 379 - * - 380
# 380 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - rpsv222.video-cloud.net - 381
# 381 - * - 382
# 382 - 6 - 383
# 383 - 443 - 384
# 384 - * - 385
# 385 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - rpsv10.video-cloud.net - 386
# 386 - * - 387
# 387 - 6 - 388
# 388 - 443 - 389
# 389 - * - 390
# 390 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - doorbells.august.com - 346
# 346 - * - 347
# 347 - 6 - 391
# 391 - 443 - 392
# 392 - * - 393
# 393 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - vcsv2.video-cloud.net - 394
# 394 - * - 395
# 395 - 6 - 396
# 396 - 443 - 397
# 397 - * - 398
# 398 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - rpsv5.video-cloud.net - 399
# 399 - * - 400
# 400 - 6 - 401
# 401 - 443 - 402
# 402 - * - 403
# 403 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 8.8.8.8/32 - 351
# 351 - * - 352
# 352 - 1 - 404
# 404 - * - 405
# 405 - * - 406
# 406 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 8.8.4.4/32 - 407
# 407 - * - 408
# 408 - 1 - 409
# 409 - * - 410
# 410 - * - 411
# 411 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - rbs-sticky.august.com - 412
# 412 - * - 413
# 413 - 6 - 414
# 414 - 443 - 415
# 415 - * - 416
# 416 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - rpsv12.video-cloud.net - 417
# 417 - * - 418
# 418 - 6 - 419
# 419 - 443 - 420
# 420 - * - 421
# 421 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 17 - 48
# 48 - * - 49
# 49 - 547 - 422
# 422 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 58 - 423
# 423 - * - 424
# 424 - * - 425
# 425 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 0 - 426
# 426 - * - 427
# 427 - * - 428
# 428 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 17 - 48
# 48 - 547 - 429
# 429 - * - 430
# 430 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ota.awair.is - 431
# 431 - 6 - 432
# 432 - * - 433
# 433 - 443 - 434
# 434 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - timeserver.awair.is - 435
# 435 - 6 - 436
# 436 - * - 437
# 437 - 443 - 438
# 438 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - messaging.awair.is - 439
# 439 - 6 - 440
# 440 - * - 441
# 441 - 8883 - 442
# 442 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - messaging.awair.is - 443
# 443 - * - 444
# 444 - 6 - 445
# 445 - 8883 - 446
# 446 - * - 447
# 447 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - timeserver.awair.is - 448
# 448 - * - 449
# 449 - 6 - 450
# 450 - 443 - 451
# 451 - * - 452
# 452 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ota.awair.is - 453
# 453 - * - 454
# 454 - 6 - 455
# 455 - 443 - 456
# 456 - * - 457
# 457 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - origin.belkin-us.tendplatform.com - 458
# 458 - 6 - 459
# 459 - * - 460
# 460 - 443 - 461
# 461 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - api.xbcs.net - 462
# 462 - 6 - 463
# 463 - * - 464
# 464 - 8443 - 465
# 465 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - * - 467
# 467 - 5104 - 468
# 468 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - * - 467
# 467 - 3478 - 469
# 469 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ping.seedonk.com - 470
# 470 - 1 - 471
# 471 - * - 472
# 472 - * - 473
# 473 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - prod1-nat-xbcs-net-1543133972.us-east-1.elb.amazonaws.com - 474
# 474 - 6 - 475
# 475 - * - 476
# 476 - 3475 - 477
# 477 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - devices.xbcs.net - 478
# 478 - 6 - 479
# 479 - * - 480
# 480 - 8899 - 481
# 481 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - 9207 - 482
# 482 - * - 483
# 483 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - time.windows.com - 484
# 484 - 17 - 485
# 485 - * - 486
# 486 - 123 - 487
# 487 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 239.255.255.250/32 - 21
# 21 - 2 - 488
# 488 - * - 489
# 489 - * - 490
# 490 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - origin.belkin-us.tendplatform.com - 458
# 458 - 6 - 459
# 459 - * - 460
# 460 - 5104 - 491
# 491 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - 49154 - 492
# 492 - * - 493
# 493 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 17 - 48
# 48 - * - 49
# 49 - * - 494
# 494 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - nat.xbcs.net - 495
# 495 - 6 - 496
# 496 - * - 497
# 497 - 3475 - 498
# 498 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 224.0.0.2/32 - 499
# 499 - 2 - 500
# 500 - * - 501
# 501 - * - 502
# 502 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.google.com - 503
# 503 - 1 - 504
# 504 - * - 505
# 505 - * - 506
# 506 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - 49153 - 507
# 507 - * - 508
# 508 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ping.seedonk.com - 509
# 509 - * - 510
# 510 - 1 - 511
# 511 - * - 512
# 512 - * - 513
# 513 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - origin.belkin-us.tendplatform.com - 514
# 514 - * - 515
# 515 - 6 - 516
# 516 - 443 - 517
# 517 - * - 518
# 518 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - origin.belkin-us.tendplatform.com - 514
# 514 - * - 515
# 515 - 6 - 516
# 516 - 5104 - 519
# 519 - * - 520
# 520 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - * - 467
# 467 - 49153 - 521
# 521 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - devices.xbcs.net - 522
# 522 - * - 523
# 523 - 6 - 524
# 524 - 8899 - 525
# 525 - * - 526
# 526 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - * - 467
# 467 - 9207 - 527
# 527 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - time.windows.com - 528
# 528 - * - 529
# 529 - 17 - 530
# 530 - 123 - 531
# 531 - * - 532
# 532 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - * - 467
# 467 - 49154 - 533
# 533 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - www.google.com - 534
# 534 - * - 535
# 535 - 1 - 536
# 536 - * - 537
# 537 - * - 538
# 538 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - 5104 - 539
# 539 - * - 540
# 540 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - prod1-nat-xbcs-net-1543133972.us-east-1.elb.amazonaws.com - 541
# 541 - * - 542
# 542 - 6 - 543
# 543 - 3475 - 544
# 544 - * - 545
# 545 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - 3478 - 546
# 546 - * - 547
# 547 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - nat.xbcs.net - 548
# 548 - * - 549
# 549 - 6 - 550
# 550 - 3475 - 551
# 551 - * - 552
# 552 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - api.xbcs.net - 553
# 553 - * - 554
# 554 - 6 - 555
# 555 - 8443 - 556
# 556 - * - 557
# 557 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 224.0.0.1/32 - 558
# 558 - 2 - 559
# 559 - * - 560
# 560 - * - 561
# 561 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - tech.carematix.com - 562
# 562 - 6 - 563
# 563 - * - 564
# 564 - 8777 - 565
# 565 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - tech.carematix.com - 566
# 566 - * - 567
# 567 - 6 - 568
# 568 - 8777 - 569
# 569 - * - 570
# 570 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - h.canaryis.com - 571
# 571 - 6 - 572
# 572 - * - 573
# 573 - 80 - 574
# 574 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - m.canaryis.com - 575
# 575 - 6 - 576
# 576 - * - 577
# 577 - 443 - 578
# 578 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ipv4.connman.net - 579
# 579 - 6 - 580
# 580 - * - 581
# 581 - 80 - 582
# 582 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - b.canaryis.com - 583
# 583 - 6 - 584
# 584 - * - 585
# 585 - 443 - 586
# 586 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 09-wl2-d-prod.canaryis.com - 587
# 587 - 6 - 588
# 588 - * - 589
# 589 - 443 - 590
# 590 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - v.canaryis.com - 591
# 591 - 6 - 592
# 592 - * - 593
# 593 - 443 - 594
# 594 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - o.canaryis.com - 595
# 595 - 6 - 596
# 596 - * - 597
# 597 - 443 - 598
# 598 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - i.canaryis.com - 599
# 599 - 6 - 600
# 600 - * - 601
# 601 - 80 - 602
# 602 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - i.canaryis.com - 599
# 599 - 6 - 600
# 600 - * - 601
# 601 - 443 - 603
# 603 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - h.canaryis.com - 571
# 571 - 6 - 572
# 572 - * - 573
# 573 - 443 - 604
# 604 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - canaryis.com - 605
# 605 - * - 606
# 606 - 6 - 607
# 607 - 443 - 608
# 608 - * - 609
# 609 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - canaryis.com - 605
# 605 - * - 606
# 606 - 6 - 607
# 607 - 443 - 608
# 608 - * - 609
# 609 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - canaryis.com - 605
# 605 - * - 606
# 606 - 6 - 607
# 607 - 80 - 610
# 610 - * - 611
# 611 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 09-wl2-d-prod.canaryis.com - 612
# 612 - * - 613
# 613 - 6 - 614
# 614 - 443 - 615
# 615 - * - 616
# 616 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - h.canaryis.com - 617
# 617 - * - 618
# 618 - 6 - 619
# 619 - 80 - 620
# 620 - * - 621
# 621 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - o.canaryis.com - 622
# 622 - * - 623
# 623 - 6 - 624
# 624 - 443 - 625
# 625 - * - 626
# 626 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - h.canaryis.com - 617
# 617 - * - 618
# 618 - 6 - 619
# 619 - 443 - 627
# 627 - * - 628
# 628 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ipv4.connman.net - 629
# 629 - * - 630
# 630 - 6 - 631
# 631 - 80 - 632
# 632 - * - 633
# 633 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - v.canaryis.com - 634
# 634 - * - 635
# 635 - 6 - 636
# 636 - 443 - 637
# 637 - * - 638
# 638 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - m.canaryis.com - 639
# 639 - * - 640
# 640 - 6 - 641
# 641 - 443 - 642
# 642 - * - 643
# 643 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ad.doubleclick.net - 644
# 644 - 6 - 645
# 645 - * - 646
# 646 - 443 - 647
# 647 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 224.0.0.251/32 - 100
# 100 - 2 - 648
# 648 - * - 649
# 649 - * - 650
# 650 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - pagead2.googlesyndication.com - 651
# 651 - 17 - 652
# 652 - * - 653
# 653 - 443 - 654
# 654 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.googleapis.com - 655
# 655 - 17 - 656
# 656 - * - 657
# 657 - 443 - 658
# 658 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ajax.googleapis.com - 659
# 659 - 6 - 660
# 660 - * - 661
# 661 - 443 - 662
# 662 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - storage.googleapis.com - 663
# 663 - 6 - 664
# 664 - * - 665
# 665 - 443 - 666
# 666 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - googleads.g.doubleclick.net - 667
# 667 - 6 - 668
# 668 - * - 669
# 669 - 443 - 670
# 670 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - tools.google.com - 671
# 671 - 17 - 672
# 672 - * - 673
# 673 - 443 - 674
# 674 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - 8009 - 675
# 675 - * - 676
# 676 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - r1---sn-55goxu-ntqe.googlevideo.com - 677
# 677 - 17 - 678
# 678 - * - 679
# 679 - 443 - 680
# 680 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - android.clients.google.com - 681
# 681 - 6 - 682
# 682 - * - 683
# 683 - 80 - 684
# 684 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - yt3.ggpht.com - 685
# 685 - 6 - 686
# 686 - * - 687
# 687 - 443 - 688
# 688 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.youtube-nocookie.com - 689
# 689 - 17 - 690
# 690 - * - 691
# 691 - 443 - 692
# 692 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ssl.gstatic.com - 693
# 693 - 6 - 694
# 694 - * - 695
# 695 - 443 - 696
# 696 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - google.com - 697
# 697 - 6 - 698
# 698 - * - 699
# 699 - 443 - 700
# 700 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - tools.google.com - 671
# 671 - 6 - 701
# 701 - * - 702
# 702 - 443 - 703
# 703 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ad.doubleclick.net - 644
# 644 - 17 - 704
# 704 - * - 705
# 705 - 443 - 706
# 706 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ssl.gstatic.com - 693
# 693 - 6 - 694
# 694 - * - 695
# 695 - 80 - 707
# 707 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - time.google.com - 708
# 708 - 17 - 709
# 709 - * - 710
# 710 - 123 - 711
# 711 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - fonts.googleapis.com - 712
# 712 - 6 - 713
# 713 - * - 714
# 714 - 443 - 715
# 715 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients4.google.com - 716
# 716 - 6 - 717
# 717 - * - 718
# 718 - 80 - 719
# 719 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - lh6.googleusercontent.com - 720
# 720 - 17 - 721
# 721 - * - 722
# 722 - 443 - 723
# 723 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.gstatic.com - 724
# 724 - 6 - 725
# 725 - * - 726
# 726 - 443 - 727
# 727 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - lh5.googleusercontent.com - 728
# 728 - 6 - 729
# 729 - * - 730
# 730 - 443 - 731
# 731 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - connectivitycheck.gstatic.com - 732
# 732 - 17 - 733
# 733 - * - 734
# 734 - 443 - 735
# 735 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - android.clients.google.com - 681
# 681 - 17 - 736
# 736 - * - 737
# 737 - 443 - 738
# 738 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - i.ytimg.com - 739
# 739 - 6 - 740
# 740 - * - 741
# 741 - 443 - 742
# 742 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ade.googlesyndication.com - 743
# 743 - 6 - 744
# 744 - * - 745
# 745 - 443 - 746
# 746 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients2.google.com - 747
# 747 - 6 - 748
# 748 - * - 749
# 749 - 443 - 750
# 750 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - fonts.googleapis.com - 712
# 712 - 17 - 751
# 751 - * - 752
# 752 - 443 - 753
# 753 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients4.google.com - 716
# 716 - 6 - 717
# 717 - * - 718
# 718 - 443 - 754
# 754 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - fonts.gstatic.com - 755
# 755 - 6 - 756
# 756 - * - 757
# 757 - 443 - 758
# 758 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - lh3.googleusercontent.com - 759
# 759 - 6 - 760
# 760 - * - 761
# 761 - 443 - 762
# 762 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - fonts.gstatic.com - 755
# 755 - 17 - 763
# 763 - * - 764
# 764 - 443 - 765
# 765 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.youtube.com - 766
# 766 - 6 - 767
# 767 - * - 768
# 768 - 80 - 769
# 769 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients1.google.com - 770
# 770 - 17 - 771
# 771 - * - 772
# 772 - 443 - 773
# 773 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.gstatic.com - 724
# 724 - 6 - 725
# 725 - * - 726
# 726 - 80 - 774
# 774 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - google.com - 697
# 697 - 6 - 698
# 698 - * - 699
# 699 - 80 - 775
# 775 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - r2---sn-ntq7yned.googlevideo.com - 776
# 776 - 17 - 777
# 777 - * - 778
# 778 - 443 - 779
# 779 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients2.google.com - 747
# 747 - 6 - 748
# 748 - * - 749
# 749 - 80 - 780
# 780 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - r4---sn-ntqe6n76.googlevideo.com - 781
# 781 - 17 - 782
# 782 - * - 783
# 783 - 443 - 784
# 784 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients3.google.com - 785
# 785 - 6 - 786
# 786 - * - 787
# 787 - 443 - 788
# 788 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - tools.google.com - 671
# 671 - 6 - 701
# 701 - * - 702
# 702 - 80 - 789
# 789 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients3.google.com - 785
# 785 - 1 - 790
# 790 - * - 791
# 791 - * - 792
# 792 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients3.google.com - 785
# 785 - 17 - 793
# 793 - * - 794
# 794 - 443 - 795
# 795 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - mtalk.google.com - 796
# 796 - 6 - 797
# 797 - * - 798
# 798 - 5228 - 799
# 799 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - storage.googleapis.com - 663
# 663 - 17 - 800
# 800 - * - 801
# 801 - 443 - 802
# 802 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - android.clients.google.com - 681
# 681 - 1 - 803
# 803 - * - 804
# 804 - * - 805
# 805 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - r3---sn-55goxu-ntqe.googlevideo.com - 806
# 806 - 17 - 807
# 807 - * - 808
# 808 - 443 - 809
# 809 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - lh4.googleusercontent.com - 810
# 810 - 17 - 811
# 811 - * - 812
# 812 - 443 - 813
# 813 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients1.google.com - 770
# 770 - 6 - 814
# 814 - * - 815
# 815 - 80 - 816
# 816 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.googleapis.com - 655
# 655 - 6 - 817
# 817 - * - 818
# 818 - 443 - 819
# 819 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - android.clients.google.com - 681
# 681 - 6 - 682
# 682 - * - 683
# 683 - 443 - 820
# 820 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - pagead2.googlesyndication.com - 651
# 651 - 6 - 821
# 821 - * - 822
# 822 - 443 - 823
# 823 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - google.com - 697
# 697 - 17 - 824
# 824 - * - 825
# 825 - 443 - 826
# 826 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - cdn.ravenjs.com - 827
# 827 - 6 - 828
# 828 - * - 829
# 829 - 443 - 830
# 830 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.gstatic.com - 724
# 724 - 17 - 831
# 831 - * - 832
# 832 - 443 - 833
# 833 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.youtube.com - 766
# 766 - 17 - 834
# 834 - * - 835
# 835 - 443 - 836
# 836 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - yt3.ggpht.com - 685
# 685 - 17 - 837
# 837 - * - 838
# 838 - 443 - 839
# 839 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - lh3.googleusercontent.com - 759
# 759 - 17 - 840
# 840 - * - 841
# 841 - 443 - 842
# 842 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - googleads.g.doubleclick.net - 667
# 667 - 17 - 843
# 843 - * - 844
# 844 - 443 - 845
# 845 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - google.com - 697
# 697 - 1 - 846
# 846 - * - 847
# 847 - * - 848
# 848 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - lh6.googleusercontent.com - 720
# 720 - 6 - 849
# 849 - * - 850
# 850 - 443 - 851
# 851 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - fonts.gstatic.com - 755
# 755 - 6 - 756
# 756 - * - 757
# 757 - 80 - 852
# 852 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients4.google.com - 716
# 716 - 1 - 853
# 853 - * - 854
# 854 - * - 855
# 855 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - connectivitycheck.gstatic.com - 732
# 732 - 6 - 856
# 856 - * - 857
# 857 - 80 - 858
# 858 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients2.google.com - 747
# 747 - 17 - 859
# 859 - * - 860
# 860 - 443 - 861
# 861 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - r1---sn-55goxu-ntqe.googlevideo.com - 677
# 677 - 6 - 862
# 862 - * - 863
# 863 - 443 - 864
# 864 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients1.google.com - 770
# 770 - 6 - 814
# 814 - * - 815
# 815 - 443 - 865
# 865 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ajax.googleapis.com - 659
# 659 - 17 - 866
# 866 - * - 867
# 867 - 443 - 868
# 868 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients1.google.com - 770
# 770 - 1 - 869
# 869 - * - 870
# 870 - * - 871
# 871 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - secure.insightexpressai.com - 872
# 872 - 6 - 873
# 873 - * - 874
# 874 - 443 - 875
# 875 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - cast.scdn.co - 876
# 876 - 6 - 877
# 877 - * - 878
# 878 - 443 - 879
# 879 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - securepubads.g.doubleclick.net - 880
# 880 - 6 - 881
# 881 - * - 882
# 882 - 443 - 883
# 883 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - tools.google.com - 671
# 671 - 1 - 884
# 884 - * - 885
# 885 - * - 886
# 886 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients4.google.com - 716
# 716 - 17 - 887
# 887 - * - 888
# 888 - 443 - 889
# 889 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - api-partner.spotify.com - 890
# 890 - 6 - 891
# 891 - * - 892
# 892 - 443 - 893
# 893 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.youtube.com - 766
# 766 - 1 - 894
# 894 - * - 895
# 895 - * - 896
# 896 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.youtube.com - 766
# 766 - 6 - 767
# 767 - * - 768
# 768 - 443 - 897
# 897 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients2.google.com - 747
# 747 - 1 - 898
# 898 - * - 899
# 899 - * - 900
# 900 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ssl.gstatic.com - 693
# 693 - 17 - 901
# 901 - * - 902
# 902 - 443 - 903
# 903 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ade.googlesyndication.com - 743
# 743 - 17 - 904
# 904 - * - 905
# 905 - 443 - 906
# 906 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - r4---sn-ntqe6n76.googlevideo.com - 781
# 781 - 6 - 907
# 907 - * - 908
# 908 - 443 - 909
# 909 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - clients3.google.com - 785
# 785 - 6 - 786
# 786 - * - 787
# 787 - 80 - 910
# 910 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - lh5.googleusercontent.com - 728
# 728 - 17 - 911
# 911 - * - 912
# 912 - 443 - 913
# 913 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - www.youtube-nocookie.com - 689
# 689 - 6 - 914
# 914 - * - 915
# 915 - 443 - 916
# 916 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - connectivitycheck.gstatic.com - 732
# 732 - 6 - 856
# 856 - * - 857
# 857 - 443 - 917
# 917 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - lh4.googleusercontent.com - 810
# 810 - 6 - 918
# 918 - * - 919
# 919 - 443 - 920
# 920 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - 8008 - 921
# 921 - * - 922
# 922 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - securepubads.g.doubleclick.net - 880
# 880 - 17 - 923
# 923 - * - 924
# 924 - 443 - 925
# 925 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - i.ytimg.com - 739
# 739 - 17 - 926
# 926 - * - 927
# 927 - 443 - 928
# 928 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ssl.gstatic.com - 929
# 929 - * - 930
# 930 - 6 - 931
# 931 - 80 - 932
# 932 - * - 933
# 933 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - cast.scdn.co - 934
# 934 - * - 935
# 935 - 6 - 936
# 936 - 443 - 937
# 937 - * - 938
# 938 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - www.youtube.com - 939
# 939 - * - 940
# 940 - 6 - 941
# 941 - 443 - 942
# 942 - * - 943
# 943 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - lh4.googleusercontent.com - 944
# 944 - * - 945
# 945 - 6 - 946
# 946 - 443 - 947
# 947 - * - 948
# 948 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - android.clients.google.com - 949
# 949 - * - 950
# 950 - 17 - 951
# 951 - 443 - 952
# 952 - * - 953
# 953 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - clients2.google.com - 954
# 954 - * - 955
# 955 - 17 - 956
# 956 - 443 - 957
# 957 - * - 958
# 958 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - www.youtube-nocookie.com - 959
# 959 - * - 960
# 960 - 17 - 961
# 961 - 443 - 962
# 962 - * - 963
# 963 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - clients3.google.com - 964
# 964 - * - 965
# 965 - 6 - 966
# 966 - 80 - 967
# 967 - * - 968
# 968 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - clients3.google.com - 964
# 964 - * - 965
# 965 - 6 - 966
# 966 - 443 - 969
# 969 - * - 970
# 970 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - r2---sn-ntq7yned.googlevideo.com - 971
# 971 - * - 972
# 972 - 17 - 973
# 973 - 443 - 974
# 974 - * - 975
# 975 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - www.gstatic.com - 976
# 976 - * - 977
# 977 - 6 - 978
# 978 - 443 - 979
# 979 - * - 980
# 980 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - googleads.g.doubleclick.net - 981
# 981 - * - 982
# 982 - 6 - 983
# 983 - 443 - 984
# 984 - * - 985
# 985 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - clients3.google.com - 964
# 964 - * - 965
# 965 - 17 - 986
# 986 - 443 - 987
# 987 - * - 988
# 988 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - clients1.google.com - 989
# 989 - * - 990
# 990 - 6 - 991
# 991 - 443 - 992
# 992 - * - 993
# 993 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - lh6.googleusercontent.com - 994
# 994 - * - 995
# 995 - 17 - 996
# 996 - 443 - 997
# 997 - * - 998
# 998 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - clients1.google.com - 989
# 989 - * - 990
# 990 - 1 - 999
# 999 - * - 1000
# 1000 - * - 1001
# 1001 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - r4---sn-ntqe6n76.googlevideo.com - 1002
# 1002 - * - 1003
# 1003 - 6 - 1004
# 1004 - 443 - 1005
# 1005 - * - 1006
# 1006 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - tools.google.com - 1007
# 1007 - * - 1008
# 1008 - 6 - 1009
# 1009 - 80 - 1010
# 1010 - * - 1011
# 1011 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - r1---sn-55goxu-ntqe.googlevideo.com - 1012
# 1012 - * - 1013
# 1013 - 17 - 1014
# 1014 - 443 - 1015
# 1015 - * - 1016
# 1016 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - r4---sn-ntqe6n76.googlevideo.com - 1002
# 1002 - * - 1003
# 1003 - 17 - 1017
# 1017 - 443 - 1018
# 1018 - * - 1019
# 1019 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - tools.google.com - 1007
# 1007 - * - 1008
# 1008 - 1 - 1020
# 1020 - * - 1021
# 1021 - * - 1022
# 1022 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - lh4.googleusercontent.com - 944
# 944 - * - 945
# 945 - 17 - 1023
# 1023 - 443 - 1024
# 1024 - * - 1025
# 1025 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - google.com - 1026
# 1026 - * - 1027
# 1027 - 1 - 1028
# 1028 - * - 1029
# 1029 - * - 1030
# 1030 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - clients4.google.com - 1031
# 1031 - * - 1032
# 1032 - 17 - 1033
# 1033 - 443 - 1034
# 1034 - * - 1035
# 1035 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - * - 467
# 467 - 8008 - 1036
# 1036 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - time.google.com - 1037
# 1037 - * - 1038
# 1038 - 17 - 1039
# 1039 - 123 - 1040
# 1040 - * - 1041
# 1041 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - mtalk.google.com - 1042
# 1042 - * - 1043
# 1043 - 6 - 1044
# 1044 - 5228 - 1045
# 1045 - * - 1046
# 1046 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - www.gstatic.com - 976
# 976 - * - 977
# 977 - 6 - 978
# 978 - 80 - 1047
# 1047 - * - 1048
# 1048 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - www.youtube.com - 939
# 939 - * - 940
# 940 - 6 - 941
# 941 - 80 - 1049
# 1049 - * - 1050
# 1050 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - lh3.googleusercontent.com - 1051
# 1051 - * - 1052
# 1052 - 17 - 1053
# 1053 - 443 - 1054
# 1054 - * - 1055
# 1055 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - fonts.gstatic.com - 1056
# 1056 - * - 1057
# 1057 - 17 - 1058
# 1058 - 443 - 1059
# 1059 - * - 1060
# 1060 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - android.clients.google.com - 949
# 949 - * - 950
# 950 - 6 - 1061
# 1061 - 443 - 1062
# 1062 - * - 1063
# 1063 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - yt3.ggpht.com - 1064
# 1064 - * - 1065
# 1065 - 17 - 1066
# 1066 - 443 - 1067
# 1067 - * - 1068
# 1068 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - securepubads.g.doubleclick.net - 1069
# 1069 - * - 1070
# 1070 - 6 - 1071
# 1071 - 443 - 1072
# 1072 - * - 1073
# 1073 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - clients2.google.com - 954
# 954 - * - 955
# 955 - 6 - 1074
# 1074 - 80 - 1075
# 1075 - * - 1076
# 1076 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - clients4.google.com - 1031
# 1031 - * - 1032
# 1032 - 1 - 1077
# 1077 - * - 1078
# 1078 - * - 1079
# 1079 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ade.googlesyndication.com - 1080
# 1080 - * - 1081
# 1081 - 6 - 1082
# 1082 - 443 - 1083
# 1083 - * - 1084
# 1084 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - fonts.gstatic.com - 1056
# 1056 - * - 1057
# 1057 - 6 - 1085
# 1085 - 443 - 1086
# 1086 - * - 1087
# 1087 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - cdn.ravenjs.com - 1088
# 1088 - * - 1089
# 1089 - 6 - 1090
# 1090 - 443 - 1091
# 1091 - * - 1092
# 1092 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - connectivitycheck.gstatic.com - 1093
# 1093 - * - 1094
# 1094 - 6 - 1095
# 1095 - 80 - 1096
# 1096 - * - 1097
# 1097 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - www.gstatic.com - 976
# 976 - * - 977
# 977 - 17 - 1098
# 1098 - 443 - 1099
# 1099 - * - 1100
# 1100 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - clients2.google.com - 954
# 954 - * - 955
# 955 - 1 - 1101
# 1101 - * - 1102
# 1102 - * - 1103
# 1103 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - secure.insightexpressai.com - 1104
# 1104 - * - 1105
# 1105 - 6 - 1106
# 1106 - 443 - 1107
# 1107 - * - 1108
# 1108 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - storage.googleapis.com - 1109
# 1109 - * - 1110
# 1110 - 6 - 1111
# 1111 - 443 - 1112
# 1112 - * - 1113
# 1113 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - fonts.googleapis.com - 1114
# 1114 - * - 1115
# 1115 - 6 - 1116
# 1116 - 443 - 1117
# 1117 - * - 1118
# 1118 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - clients4.google.com - 1031
# 1031 - * - 1032
# 1032 - 6 - 1119
# 1119 - 443 - 1120
# 1120 - * - 1121
# 1121 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ajax.googleapis.com - 1122
# 1122 - * - 1123
# 1123 - 17 - 1124
# 1124 - 443 - 1125
# 1125 - * - 1126
# 1126 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - connectivitycheck.gstatic.com - 1093
# 1093 - * - 1094
# 1094 - 17 - 1127
# 1127 - 443 - 1128
# 1128 - * - 1129
# 1129 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - google.com - 1026
# 1026 - * - 1027
# 1027 - 6 - 1130
# 1130 - 443 - 1131
# 1131 - * - 1132
# 1132 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - www.youtube.com - 939
# 939 - * - 940
# 940 - 1 - 1133
# 1133 - * - 1134
# 1134 - * - 1135
# 1135 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - www.youtube-nocookie.com - 959
# 959 - * - 960
# 960 - 6 - 1136
# 1136 - 443 - 1137
# 1137 - * - 1138
# 1138 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - r3---sn-55goxu-ntqe.googlevideo.com - 1139
# 1139 - * - 1140
# 1140 - 17 - 1141
# 1141 - 443 - 1142
# 1142 - * - 1143
# 1143 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - api-partner.spotify.com - 1144
# 1144 - * - 1145
# 1145 - 6 - 1146
# 1146 - 443 - 1147
# 1147 - * - 1148
# 1148 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - lh6.googleusercontent.com - 994
# 994 - * - 995
# 995 - 6 - 1149
# 1149 - 443 - 1150
# 1150 - * - 1151
# 1151 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - clients2.google.com - 954
# 954 - * - 955
# 955 - 6 - 1074
# 1074 - 443 - 1152
# 1152 - * - 1153
# 1153 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - lh5.googleusercontent.com - 1154
# 1154 - * - 1155
# 1155 - 17 - 1156
# 1156 - 443 - 1157
# 1157 - * - 1158
# 1158 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ade.googlesyndication.com - 1080
# 1080 - * - 1081
# 1081 - 17 - 1159
# 1159 - 443 - 1160
# 1160 - * - 1161
# 1161 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - android.clients.google.com - 949
# 949 - * - 950
# 950 - 1 - 1162
# 1162 - * - 1163
# 1163 - * - 1164
# 1164 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - storage.googleapis.com - 1109
# 1109 - * - 1110
# 1110 - 17 - 1165
# 1165 - 443 - 1166
# 1166 - * - 1167
# 1167 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - clients4.google.com - 1031
# 1031 - * - 1032
# 1032 - 6 - 1119
# 1119 - 80 - 1168
# 1168 - * - 1169
# 1169 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - pagead2.googlesyndication.com - 1170
# 1170 - * - 1171
# 1171 - 17 - 1172
# 1172 - 443 - 1173
# 1173 - * - 1174
# 1174 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - * - 467
# 467 - 8009 - 1175
# 1175 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ad.doubleclick.net - 1176
# 1176 - * - 1177
# 1177 - 6 - 1178
# 1178 - 443 - 1179
# 1179 - * - 1180
# 1180 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - google.com - 1026
# 1026 - * - 1027
# 1027 - 6 - 1130
# 1130 - 80 - 1181
# 1181 - * - 1182
# 1182 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - lh3.googleusercontent.com - 1051
# 1051 - * - 1052
# 1052 - 6 - 1183
# 1183 - 443 - 1184
# 1184 - * - 1185
# 1185 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - google.com - 1026
# 1026 - * - 1027
# 1027 - 17 - 1186
# 1186 - 443 - 1187
# 1187 - * - 1188
# 1188 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - android.clients.google.com - 949
# 949 - * - 950
# 950 - 6 - 1061
# 1061 - 80 - 1189
# ...
# 1403 - 6 - 1404
# 1404 - * - 1405
# 1405 - 80 - 1406
# 1406 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ipcserv.tplinkcloud.com - 1387
# 1387 - 6 - 1388
# 1388 - * - 1389
# 1389 - 443 - 1407
# 1407 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 0.pool.ntp.org - 1408
# 1408 - * - 1409
# 1409 - 17 - 1410
# 1410 - 123 - 1411
# 1411 - * - 1412
# 1412 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ipc.tplinkcloud.com - 1413
# 1413 - * - 1414
# 1414 - 6 - 1415
# 1415 - 80 - 1416
# 1416 - * - 1417
# 1417 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ipcserv.tplinkcloud.com - 1418
# 1418 - * - 1419
# 1419 - 6 - 1420
# 1420 - 443 - 1421
# 1421 - * - 1422
# 1422 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ipcserv.tplinkcloud.com - 1418
# 1418 - * - 1419
# 1419 - 6 - 1420
# 1420 - 80 - 1423
# 1423 - * - 1424
# 1424 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - sg-stun.tplinkcloud.com - 1425
# 1425 - * - 1426
# 1426 - 17 - 1427
# 1427 - 3478 - 1428
# 1428 - * - 1429
# 1429 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - devs.tplinkcloud.com - 1430
# 1430 - * - 1431
# 1431 - 6 - 1432
# 1432 - 443 - 1433
# 1433 - * - 1434
# 1434 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - * - 467
# 467 - 8080 - 1435
# 1435 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - aps1-relay.tplinkcloud.com - 1436
# 1436 - * - 1437
# 1437 - 6 - 1438
# 1438 - 80 - 1439
# 1439 - * - 1440
# 1440 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ipc.tplinkcloud.com - 1413
# 1413 - * - 1414
# 1414 - 6 - 1415
# 1415 - 443 - 1441
# 1441 - * - 1442
# 1442 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ru.pool.ntp.org - 1443
# 1443 - 17 - 1444
# 1444 - * - 1445
# 1445 - 123 - 1446
# 1446 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - devs.tplinkcloud.com - 1391
# 1391 - 6 - 1392
# 1392 - * - 1393
# 1393 - 50443 - 1447
# 1447 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - de.pool.ntp.org - 1448
# 1448 - 17 - 1449
# 1449 - * - 1449
# 1449 - 123 - 1450
# 1450 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - s1b.time.edu.cn - 1451
# 1451 - 17 - 1452
# 1452 - * - 1453
# 1453 - 123 - 1454
# 1454 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - time-b.nist.gov - 1455
# 1455 - 17 - 1456
# 1456 - * - 1457
# 1457 - 123 - 1458
# 1458 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 0.cn.pool.ntp.org - 1459
# 1459 - 17 - 1460
# 1460 - * - 1461
# 1461 - 123 - 1462
# 1462 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 17 - 48
# 48 - 9999 - 1463
# 1463 - * - 1464
# 1464 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 1.asia.pool.ntp.org - 1465
# 1465 - 17 - 1466
# 1466 - * - 1467
# 1467 - 123 - 1468
# 1468 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ca.pool.ntp.org - 1469
# 1469 - 17 - 1470
# 1470 - * - 1471
# 1471 - 123 - 1472
# 1472 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - us.pool.ntp.org - 1473
# 1473 - 17 - 1474
# 1474 - * - 1475
# 1475 - 123 - 1476
# 1476 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - uk.pool.ntp.org - 1477
# 1477 - 17 - 1478
# 1478 - * - 1479
# 1479 - 123 - 1480
# 1480 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - fr.pool.ntp.org - 1481
# 1481 - 17 - 1482
# 1482 - * - 1483
# 1483 - 123 - 1484
# 1484 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - 9999 - 1485
# 1485 - * - 1486
# 1486 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - s1b.time.edu.cn - 1487
# 1487 - * - 1488
# 1488 - 17 - 1488
# 1488 - 123 - 1489
# 1489 - * - 1490
# 1490 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - fr.pool.ntp.org - 1491
# 1491 - * - 1492
# 1492 - 17 - 1493
# 1493 - 123 - 1494
# 1494 - * - 1495
# 1495 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - de.pool.ntp.org - 1496
# 1496 - * - 1497
# 1497 - 17 - 1498
# 1498 - 123 - 1499
# 1499 - * - 1500
# 1500 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - us.pool.ntp.org - 1501
# 1501 - * - 1502
# 1502 - 17 - 1503
# 1503 - 123 - 1504
# 1504 - * - 1505
# 1505 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ca.pool.ntp.org - 1506
# 1506 - * - 1507
# 1507 - 17 - 1508
# 1508 - 123 - 1509
# 1509 - * - 1510
# 1510 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 0.cn.pool.ntp.org - 1511
# 1511 - * - 1512
# 1512 - 17 - 1513
# 1513 - 123 - 1514
# 1514 - * - 1515
# 1515 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - uk.pool.ntp.org - 1516
# 1516 - * - 1517
# 1517 - 17 - 1518
# 1518 - 123 - 1519
# 1519 - * - 1520
# 1520 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - time-b.nist.gov - 1521
# 1521 - * - 1522
# 1522 - 17 - 1523
# 1523 - 123 - 1524
# 1524 - * - 1525
# 1525 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - * - 40
# 40 - 6 - 466
# 466 - * - 467
# 467 - 9999 - 1526
# 1526 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ru.pool.ntp.org - 1527
# 1527 - * - 1528
# 1528 - 17 - 1529
# 1529 - 123 - 1530
# 1530 - * - 1531
# 1531 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 1.asia.pool.ntp.org - 1532
# 1532 - * - 1533
# 1533 - 17 - 1534
# 1534 - 123 - 1535
# 1535 - * - 1536
# 1536 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - devs.tplinkcloud.com - 1430
# 1430 - * - 1431
# 1431 - 6 - 1432
# 1432 - 50443 - 1537
# 1537 - * - 1538
# 1538 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - sip.aws.invoxia.io - 1539
# 1539 - 17 - 1540
# 1540 - * - 1541
# 1541 - 10003 - 1542
# 1542 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - crossbar.invoxia.io - 1543
# 1543 - 6 - 1544
# 1544 - * - 1545
# 1545 - 8090 - 1546
# 1546 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - playerservices.streamtheworld.com - 1547
# 1547 - 6 - 1548
# 1548 - * - 1549
# 1549 - 80 - 1550
# 1550 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 0.invoxia.pool.ntp.org - 1551
# 1551 - 17 - 1552
# 1552 - * - 1553
# 1553 - 123 - 1554
# 1554 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 2.invoxia.pool.ntp.org - 1555
# 1555 - 17 - 1556
# 1556 - * - 1557
# 1557 - 123 - 1558
# 1558 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - sip.aws.invoxia.io - 1539
# 1539 - 17 - 1540
# 1540 - * - 1541
# 1541 - 10002 - 1559
# 1559 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 18393.live.streamtheworld.com - 1560
# 1560 - 6 - 1561
# 1561 - * - 1562
# 1562 - 80 - 1562
# 1562 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 1129153316.airable.io - 1563
# 1563 - 6 - 1564
# 1564 - * - 1565
# 1565 - 80 - 1566
# 1566 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - whatismyip.akamai.com - 1567
# 1567 - 6 - 1568
# 1568 - * - 1569
# 1569 - 80 - 1570
# 1570 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - sip.aws.invoxia.io - 1539
# 1539 - 6 - 1571
# 1571 - * - 1572
# 1572 - 5228 - 1573
# 1573 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - streaming.novaentertainment.com.au - 1574
# 1574 - 6 - 1575
# 1575 - * - 1576
# 1576 - 80 - 1577
# 1577 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - ws.invoxia.io - 1578
# 1578 - 6 - 1579
# 1579 - * - 1580
# 1580 - 443 - 1581
# 1581 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 3.invoxia.pool.ntp.org - 1582
# 1582 - 17 - 1583
# 1583 - * - 1584
# 1584 - 123 - 1585
# 1585 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - esdk-ffl.spotify.com - 1586
# 1586 - 6 - 1587
# 1587 - * - 1588
# 1588 - 80 - 1589
# 1589 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - developer.invoxia.com - 1590
# 1590 - 6 - 1591
# 1591 - * - 1592
# 1592 - 80 - 1593
# 1593 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 15373.live.streamtheworld.com - 1594
# 1594 - 6 - 1595
# 1595 - * - 1596
# 1596 - 80 - 1597
# 1597 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 1129153316.airable.io - 1598
# 1598 - * - 1599
# 1599 - 6 - 1600
# 1600 - 80 - 1601
# 1601 - * - 1602
# 1602 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - invoxia.pool.ntp.org - 1603
# 1603 - * - 1604
# 1604 - 17 - 1605
# 1605 - 123 - 1606
# 1606 - * - 1607
# 1607 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - streaming.novaentertainment.com.au - 1608
# 1608 - * - 1609
# 1609 - 6 - 1610
# 1610 - 80 - 1611
# 1611 - * - 1612
# 1612 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - playerservices.streamtheworld.com - 1613
# 1613 - * - 1614
# 1614 - 6 - 1615
# 1615 - 80 - 1616
# 1616 - * - 1617
# 1617 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 18393.live.streamtheworld.com - 1618
# 1618 - * - 1619
# 1619 - 6 - 1620
# 1620 - 80 - 1621
# 1621 - * - 1622
# 1622 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 15373.live.streamtheworld.com - 1623
# 1623 - * - 1624
# 1624 - 6 - 1625
# 1625 - 80 - 1625
# 1625 - * - 1626
# 1626 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - sip.aws.invoxia.io - 1627
# 1627 - * - 1628
# 1628 - 6 - 1629
# 1629 - 5228 - 1629
# 1629 - * - 1630
# 1630 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - sip.aws.invoxia.io - 1627
# 1627 - * - 1628
# 1628 - 17 - 1631
# 1631 - 10002 - 1632
# 1632 - * - 1633
# 1633 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - developer.invoxia.com - 1634
# 1634 - * - 1635
# 1635 - 6 - 1636
# 1636 - 80 - 1637
# 1637 - * - 1638
# 1638 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - whatismyip.akamai.com - 1639
# 1639 - * - 1640
# 1640 - 6 - 1641
# 1641 - 80 - 1641
# 1641 - * - 1642
# 1642 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - ws.invoxia.io - 1643
# 1643 - * - 1644
# 1644 - 6 - 1645
# 1645 - 443 - 1645
# 1645 - * - 1646
# 1646 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - esdk-ffl.spotify.com - 1647
# 1647 - * - 1648
# 1648 - 6 - 1649
# 1649 - 80 - 1649
# 1649 - * - 1650
# 1650 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - invoxia.pool.ntp.org - 1603
# 1603 - * - 1604
# 1604 - 17 - 1605
# 1605 - 123 - 1606
# 1606 - * - 1607
# 1607 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - invoxia.pool.ntp.org - 1603
# 1603 - * - 1604
# 1604 - 17 - 1605
# 1605 - 123 - 1606
# 1606 - * - 1607
# 1607 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - crossbar.invoxia.io - 1608
# 1608 - * - 1609
# 1609 - 6 - 1610
# 1610 - 8090 - 1610
# 1610 - * - 1611
# 1611 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - xbcs.net - 1612
# 1612 - 6 - 1613
# 1613 - * - 1614
# 1614 - 8443 - 1614
# 1614 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 129.132.2.21/32 - 1615
# 1615 - 17 - 1616
# 1616 - * - 1617
# 1617 - 123 - 1618
# 1618 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - tunnel.xbcs.net - 1619
# 1619 - 6 - 1620
# 1620 - * - 1620
# 1620 - 3478 - 1621
# 1621 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 132.163.4.102/32 - 1622
# 1622 - 17 - 1623
# 1623 - * - 1624
# 1624 - 123 - 1625
# 1625 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 129.132.2.21/32 - 1626
# 1626 - * - 1627
# 1627 - 17 - 1628
# 1628 - 123 - 1629
# 1629 - * - 1630
# 1630 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - xbcs.net - 1631
# 1631 - * - 1632
# 1632 - 6 - 1633
# 1633 - 8443 - 1633
# 1633 - * - 1634
# 1634 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 132.163.4.102/32 - 1635
# 1635 - * - 1636
# 1636 - 17 - 1637
# 1637 - 123 - 1638
# 1638 - * - 1639
# 1639 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - tunnel.xbcs.net - 1640
# 1640 - * - 1641
# 1641 - 6 - 1641
# 1641 - 3478 - 1641
# 1641 - * - 1642
# 1642 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 208.67.222.222/32 - 1643
# 1643 - 1 - 1644
# 1644 - * - 1645
# 1645 - * - 1646
# 1646 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 4.2.2.2/32 - 1647
# 1647 - 1 - 1648
# 1648 - * - 1649
# 1649 - * - 1650
# 1650 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - 130.149.17.8/32 - 1651
# 1651 - 17 - 1652
# 1652 - * - 1653
# 1653 - 123 - 1654
# 1654 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 130.149.17.8/32 - 1655
# 1655 - * - 1656
# 1656 - 17 - 1657
# 1657 - 123 - 1658
# 1658 - * - 1659
# 1659 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 4.2.2.2/32 - 1660
# 1660 - * - 1661
# 1661 - 1 - 1662
# 1662 - * - 1663
# 1663 - * - 1664
# 1664 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - 208.67.222.222/32 - 1665
# 1665 - * - 1666
# 1666 - 1 - 1667
# 1667 - * - 1668
# 1668 - * - 1669
# 1669 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - fr-eqx-fwd-06.withings.com - 1670
# 1670 - 6 - 1671
# 1671 - * - 1672
# 1672 - 1935 - 1673
# 1673 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - fr-on-fwd-03.withings.net - 1674
# 1674 - 6 - 1675
# 1675 - * - 1676
# 1676 - 1935 - 1677
# 1677 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - fr-on-vm-02-lxc-03.withings.net - 1678
# 1678 - 6 - 1679
# 1679 - * - 1680
# 1680 - 1935 - 1681
# 1681 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - fr-on-vm-02-lxc-05.withings.net - 1682
# 1682 - 6 - 1683
# 1683 - * - 1684
# 1684 - 1935 - 1685
# 1685 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - us-iweb-fwd-01-lxc-04.withings.net - 1686
# 1686 - 6 - 1687
# 1687 - * - 1688
# 1688 - 1935 - 1689
# 1689 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - fr-ovh-fwd-03.withings.net - 1690
# 1690 - 6 - 1691
# 1691 - * - 1692
# 1692 - 1935 - 1693
# 1693 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - babyws.withings.net - 1694
# 1694 - 6 - 1695
# 1695 - * - 1696
# 1696 - 80 - 1697
# 1697 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - babyws.withings.net - 1698
# 1698 - * - 1699
# 1699 - 6 - 1700
# 1700 - 80 - 1701
# 1701 - * - 1702
# 1702 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - fr-on-vm-02-lxc-03.withings.net - 1703
# 1703 - * - 1704
# 1704 - 6 - 1705
# 1705 - 1935 - 1706
# 1706 - * - 1707
# 1707 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - fr-ovh-fwd-03.withings.net - 1708
# 1708 - * - 1709
# 1709 - 6 - 1710
# 1710 - 1935 - 1710
# 1710 - * - 1711
# 1711 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - fr-on-fwd-03.withings.net - 1712
# 1712 - * - 1713
# 1713 - 6 - 1714
# 1714 - 1935 - 1714
# 1714 - * - 1715
# 1715 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - fr-on-vm-02-lxc-05.withings.net - 1716
# 1716 - * - 1717
# 1717 - 6 - 1718
# 1718 - 1935 - 1719
# 1719 - * - 1720
# 1720 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - fr-eqx-fwd-06.withings.com - 1721
# 1721 - * - 1722
# 1722 - 6 - 1723
# 1723 - 1935 - 1724
# 1724 - * - 1725
# 1725 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - us-iweb-fwd-01-lxc-04.withings.net - 1726
# 1726 - * - 1727
# 1727 - 6 - 1728
# 1728 - 1935 - 1729
# 1729 - * - 1730
# 1730 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - wbs04-ws.withings.net - 1731
# 1731 - 6 - 1732
# 1732 - * - 1733
# 1733 - 443 - 1734
# 1734 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - wbs04-ws.withings.net - 1735
# 1735 - * - 1736
# 1736 - 6 - 1737
# 1737 - 443 - 1738
# 1738 - * - 1739
# 1739 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - scalews.withings.net - 1740
# 1740 - 6 - 1741
# 1741 - * - 1742
# 1742 - 443 - 1743
# 1743 - forward
# 9e:8d:de:80:29:28 - 1
# 1 - * - 2
# 2 - * - 3
# 3 - * - 4
# 4 - scalews.withings.net - 1740
# 1740 - 6 - 1741
# 1741 - * - 1742
# 1742 - 80 - 1744
# 1744 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - scalews.withings.net - 1745
# 1745 - * - 1746
# 1746 - 6 - 1747
# 1747 - 443 - 1748
# 1748 - * - 1749
# 1749 - forward
# * - 120
# 120 - 9e:8d:de:80:29:28 - 121
# 121 - * - 122
# 122 - scalews.withings.net - 1745
# 1745 - * - 1746
# 1746 - 6 - 1747
# 1747 - 80 - 1750
# 1750 - * - 1751
# 1751 - forward
# * - 120
# 120 - * - 1752
# 1752 - * - 1753
# 1753 - * - 1754
# 1754 - * - 1755
# 1755 - * - 1756
# 1756 - * - 1757
# 1757 - * - 1758
# 1758 - deny
