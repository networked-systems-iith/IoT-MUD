# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import networkx as nx

# %%
G=nx.Graph()

# %%
data = pd.read_csv("E:/PhD/Bit Vector Linear Search/data_final2.csv")
data.head()
# Out:
#                 sEth               dEth  typEth           Source  \
# 0  9e:8d:de:80:29:28  ff:ff:ff:ff:ff:ff  0x0800  s1b.time.edu.cn
# 1                  *  9e:8d:de:80:29:28  0x0800  fr.pool.ntp.org
# 2  9e:8d:de:80:29:28  ff:ff:ff:ff:ff:ff  0x0800  de.pool.ntp.org
# 3  9e:8d:de:80:29:28  ff:ff:ff:ff:ff:ff  0x0006  us.pool.ntp.org
# 4                  *  9e:8d:de:80:29:28  0x0800  ca.pool.ntp.org
#
#                     Destination proto sPort  dPort   action
# 0           dcape-na.amazon.com    17   123    443  forward
# 1    softwareupdates.amazon.com    17   123     80  forward
# 2  3.north-america.pool.ntp.org    17   123     53  forward
# 3                 224.0.0.22/32    17   123     67  forward
# 4            239.255.255.250/32    17   123  33434  forward

# %%
column_list=data.columns

# %%
print(column_list)
# Out:
# Index(['sEth', 'dEth', 'typEth', 'Source', 'Destination', 'proto', 'sPort',
#        'dPort', 'action'],
#       dtype='object')

# %%
for i in range(len(column_list)):
    print(column_list[i])
# Out:
# sEth
# dEth
# typEth
# Source
# Destination
# proto
# sPort
# dPort
# action

# %%
datalist=data.values.tolist()
print(datalist)
# Out:
# [['9e:8d:de:80:29:28', 'ff:ff:ff:ff:ff:ff', '0x0800', 's1b.time.edu.cn', 'dcape-na.amazon.com', '17', '123', '443', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', 'fr.pool.ntp.org', 'softwareupdates.amazon.com', '17', '123', '80', 'forward'], ['9e:8d:de:80:29:28', 'ff:ff:ff:ff:ff:ff', '0x0800', 'de.pool.ntp.org', '3.north-america.pool.ntp.org', '17', '123', '53', 'forward'], ['9e:8d:de:80:29:28', 'ff:ff:ff:ff:ff:ff', '0x0006', 'us.pool.ntp.org', '224.0.0.22/32', '17', '123', '67', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', 'ca.pool.ntp.org', '239.255.255.250/32', '17', '123', '33434', 'forward'], ['9e:8d:de:80:29:28', 'ff:ff:ff:ff:ff:ff', '0x0800', '0.cn.pool.ntp.org', '255.255.255.255/32', '17', '123', '50000', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', 'uk.pool.ntp.org', 'ntp-g7g.amazon.com', '17', '123', '3478', 'forward'], ['*', '9e:8d:de:80:29:28', '0x0800', 'time-b.nist.gov', 'todo-ta-g7g.amazon.com', '17', '123', '5104', 'forward'], ['9e:8d:de:80:29:28', 'ff:ff:f
# ...

# %%
class BinarySearchTreeNode:
    def __init__(self, data):
        
        self.data = data
        self.left = None
        self.right = None
        #counter=0

    def add_child(self, data,c):
        #counter=0
        if data == self.data:
            if data!='*':
                if self.right:
                    self.right.add_child(data,c)
            else:
                    self.right = BinarySearchTreeNode(data)
                    G.add_node(data,pos=(5,8))
                    G.add_edge(self.data, data, weight=c)
                    #counter=counter+1
                    #c=c+1
                    #counter1=c
                    #print(c)
                    
                
                    
                

        if data != self.data:
            if self.left:
                 if data!='*':
                    self.left.add_child(data,c)
            else:
                self.left = BinarySearchTreeNode(data)
                G.add_node(data,pos=(5,8))
                G.add_edge(self.data, data, weight=c)
                #counter=counter+1
                #c=c+1
                #counter1=c
                #print(c)
                
                    
def build_tree(elements,count):
    #counter=0
    print("Building tree with these elements:",elements)
    for i in range(len(elements)):
        #root=BinarySearchTreeNode(elements[0])
        if (elements[i]!='*'):
            root = BinarySearchTreeNode(elements[i])
            print(root)
            break
        
        #if (elements[i]!='*'):
            #break
       # root = BinarySearchTreeNode(elements[i])
        #print(elements[i])
    
    #root = BinarySearchTreeNode(elements[i])       
        
    for i in range(1,len(elements)):
        #print (column_list[i])
        if (elements[i]!='*'):
            #counter=counter+1
            count=count+1
            root.add_child(column_list[i]+elements[i],count)#counter)
            
            #print(counter)
       
    return root
    return count

# %%
if __name__ == '__main__':
    i=4
    
    data1 = datalist[i]
   
   # countries2 = datalist[0]
    #data2=datalist[1]
    #data3=datalist[2]
    #data4=datalist[3]
    #data5=datalist[4]
    #data6=datalist[5]
    #counter=counter+1
    
    if i==1:
        counter=0
    else:
        for j in range(len(datalist[i])):
            temp=j
        counter=counter+j
        print(counter)
    country_tree = build_tree(data1,counter)
    #country_tree = build_tree(data1,counter1)
# Out:
# 24
# Building tree with these elements: ['*', '9e:8d:de:80:29:28', '0x0800', 'ca.pool.ntp.org', '239.255.255.250/32', '17', '123', '33434', 'forward']
# ...

# %%
pos=nx.spring_layout(G)
nx.draw(G,pos, with_labels=True)
labels=nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# {('dEth9e:8d:de:80:29:28',
#   '9e:8d:de:80:29:28'): Text(-0.8346209856545257, -0.0064989821781267845, '1'),
#  ('dEth9e:8d:de:80:29:28',
#   'typEth0x0800'): Text(-0.5216245302256172, -0.16120141241912772, '2'),
#  ('typEth0x0800',
#   'Sourcefr.pool.ntp.org'): Text(-0.22846681845000813, -0.2608601834420134, '3'),
#  ('Sourcefr.pool.ntp.org',
#   'Destinationsoftwareupdates.amazon.com'): Text(0.05247885505239488, -0.2674137931869147, '4'),
#  ('Destinationsoftwareupdates.amazon.com',
#   'proto17'): Text(0.2887948325638311, -0.17391101893583882, '5'),
#  ('proto17',
#   'sPort123'): Text(0.4436517165002233, -0.0010326854480822711, '6'),
#  ('sPort123', 'dPort80'): Text(0.5092179209443186, 0.2029766122796875, '7'),
#  ('dPort80',
#   'actionforward'): Text(0.5254939586729992, 0.39128110633823787, '8')}

# %%
pos=nx.spring_layout(G)
nx.draw(G,pos, with_labels=True)
labels=nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# {('dEth9e:8d:de:80:29:28',
#   '9e:8d:de:80:29:28'): Text(0.9178153221845617, -0.461086611303826, '1'),
#  ('dEth9e:8d:de:80:29:28',
#   'typEth0x0800'): Text(0.6547680133332706, -0.4454597666626724, '2'),
#  ('9e:8d:de:80:29:28',
#   'dEthff:ff:ff:ff:ff:ff'): Text(0.8790891555806272, -0.2827906457626642, '9'),
#  ('typEth0x0800',
#   'Sourcefr.pool.ntp.org'): Text(0.27226116179493415, -0.34660467095137176, '3'),
#  ('typEth0x0800',
#   'dEthff:ff:ff:ff:ff:ff'): Text(0.6160418467293362, -0.2671638011215106, '10'),
#  ('typEth0x0800',
#   'Sourcede.pool.ntp.org'): Text(0.3565317345671269, -0.16782454271970618, '11'),
#  ('Sourcefr.pool.ntp.org',
#   'Destinationsoftwareupdates.amazon.com'): Text(-0.08393695408350982, -0.3220010691157259, '4'),
#  ('Destinationsoftwareupdates.amazon.com',
#   'proto17'): Text(-0.26784882684063394, -0.04032958174695747, '5'),
#  ('proto17', 'sPort123'): Text(-0.41380759052347216, 0.2415859556050581, '14'),
#  ('proto17',
# ...

# %%
pos=nx.spring_layout(G)
nx.draw(G,pos, with_labels=True)
labels=nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# {('dEth9e:8d:de:80:29:28',
#   '9e:8d:de:80:29:28'): Text(-0.24779667144850365, -0.9357138328253909, '1'),
#  ('dEth9e:8d:de:80:29:28',
#   'typEth0x0800'): Text(-0.3747509005006294, -0.7562653433740083, '2'),
#  ('9e:8d:de:80:29:28',
#   'dEthff:ff:ff:ff:ff:ff'): Text(-0.01920608289098439, -0.7610482873779745, '17'),
#  ('typEth0x0800',
#   'Sourcefr.pool.ntp.org'): Text(-0.43198923923108445, -0.3305695152047808, '3'),
#  ('typEth0x0800',
#   'dEthff:ff:ff:ff:ff:ff'): Text(-0.14616031194311016, -0.5815997979265919, '10'),
#  ('typEth0x0800',
#   'Sourcede.pool.ntp.org'): Text(-0.262155525470046, -0.3789383944495064, '11'),
#  ('Sourcefr.pool.ntp.org',
#   'Destinationsoftwareupdates.amazon.com'): Text(-0.4660710986146629, 0.015220263034436299, '4'),
#  ('Destinationsoftwareupdates.amazon.com',
#   'proto17'): Text(-0.1404008783352408, 0.21057835104172035, '5'),
#  ('proto17', 'sPort123'): Text(0.1304472543011795, 0.3929587859281231, '22'),
#  ('proto17',
# ...

# %%
pos=nx.spring_layout(G)
nx.draw(G,pos, with_labels=True)
labels=nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# {('dEth9e:8d:de:80:29:28',
#   '9e:8d:de:80:29:28'): Text(0.872294190143883, 0.1586084109789368, '25'),
#  ('dEth9e:8d:de:80:29:28',
#   'typEth0x0800'): Text(0.6475164933392763, 0.16849724586109466, '26'),
#  ('9e:8d:de:80:29:28',
#   'dEthff:ff:ff:ff:ff:ff'): Text(0.8895060662525609, 0.04826952243719727, '17'),
#  ('typEth0x0800',
#   'Sourcefr.pool.ntp.org'): Text(0.39631728819532996, 0.4048732032747058, '3'),
#  ('typEth0x0800',
#   'dEthff:ff:ff:ff:ff:ff'): Text(0.6647283694479541, 0.058158357319355154, '10'),
#  ('typEth0x0800',
#   'Sourcede.pool.ntp.org'): Text(0.4109877206824038, -0.039001982557214154, '11'),
#  ('typEth0x0800',
#   'Sourceca.pool.ntp.org'): Text(0.38968508005529756, 0.1706182793081944, '27'),
#  ('Sourcefr.pool.ntp.org',
#   'Destinationsoftwareupdates.amazon.com'): Text(0.07679437696566896, 0.5856247734164555, '4'),
#  ('Destinationsoftwareupdates.amazon.com',
#   'proto17'): Text(-0.16387615691726476, 0.24509249557375792, '5'),
#  ('proto17',
# ...
